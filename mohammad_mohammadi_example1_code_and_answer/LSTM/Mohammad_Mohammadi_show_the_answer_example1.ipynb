# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# بستن تمام پنجره‌های نمودار باز
plt.close('all')

# بارگذاری داده‌ها از فایل CSV
df = pd.read_csv('example1.csv')

# دریافت لیست نام ستون‌ها
df_columns = list(df.columns)

# انتخاب ستون مورد نظر برای نمایش داده‌ها
selected_column = df_columns[8]

# انتخاب 100 داده اول از ستون مورد نظر
data_to_plot = df[selected_column][:99].values.reshape(-1,1)  # تبدیل به آرایه دو بعدی برای مقیاس‌بندی

# مقیاس‌بندی داده‌ها
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_to_plot)

# تقسیم داده‌ها به دو بخش آموزشی و تست
train_size = int(len(scaled_data) * 0.67)
test_size = len(scaled_data) - train_size
train, test = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# تابع برای ایجاد داده‌های آموزشی
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# ایجاد داده‌های آموزشی و تست
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# تغییر شکل ورودی‌ها برای LSTM
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# ایجاد و آموزش شبکه LSTM
model = Sequential()
model.add(LSTM(100, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2, validation_data=(testX, testY))

# پیش‌بینی‌ها
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# تبدیل پیش‌بینی‌ها به مقیاس اصلی
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# تعداد نقاط داده‌ای که می‌خواهیم پیش‌بینی کنیم
num_future_points = 20

# آخرین نقطه داده‌ای از مجموعه داده‌های آموزشی
last_point = trainX[-1]

# لیست برای نگهداری پیش‌بینی‌های آینده
future_predictions = []

# حلقه برای پیش‌بینی نقاط داده‌های آینده
for _ in range(num_future_points):
    # پیش‌بینی با استفاده از آخرین نقطه داده‌ای
    prediction = model.predict(last_point.reshape(1, 1, look_back))

    # اضافه کردن پیش‌بینی به لیست
    future_predictions.append(prediction[0,0])

    # به‌روزرسانی آخرین نقطه داده‌ای با استفاده از پیش‌بینی جدید
    last_point = np.roll(last_point, -1)
    last_point[-1] = prediction

# تبدیل پیش‌بینی‌های آینده به مقیاس اصلی
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# نمایش نمودارها
plt.figure(figsize=(10, 5))
plt.plot(trainY[0], label='Actual')
plt.plot(trainPredict[:,0], label='Predicted')
plt.title('Mohammad Mohammadi show the answer \n Train Data vs Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(testY[0], label='Actual')
plt.plot(testPredict[:,0], label='Predicted')
plt.title('Test Data vs Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()



# اضافه کردن پیش‌بینی‌های آینده به نمودار
plt.figure(figsize=(10, 5))
plt.plot(range(len(trainY[0])), trainY[0], label='Actual')
plt.plot(range(len(trainPredict[:,0])), trainPredict[:,0], label='Predicted')
plt.plot(range(len(trainY[0]), len(trainY[0])+num_future_points), future_predictions[:,0], label='Future Predicted')
plt.title('Train Data vs Predicted Data vs Future Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 64/64 - 3s - loss: 0.1328 - val_loss: 0.0157 - 3s/epoch - 40ms/step
# Epoch 2/200
# 64/64 - 0s - loss: 0.0536 - val_loss: 0.0277 - 232ms/epoch - 4ms/step
# Epoch 3/200
# 64/64 - 0s - loss: 0.0428 - val_loss: 0.0227 - 259ms/epoch - 4ms/step
# Epoch 4/200
# 64/64 - 0s - loss: 0.0394 - val_loss: 0.0185 - 269ms/epoch - 4ms/step
# Epoch 5/200
# 64/64 - 0s - loss: 0.0355 - val_loss: 0.0173 - 241ms/epoch - 4ms/step
# Epoch 6/200
# 64/64 - 0s - loss: 0.0331 - val_loss: 0.0131 - 239ms/epoch - 4ms/step
# Epoch 7/200
# 64/64 - 0s - loss: 0.0304 - val_loss: 0.0140 - 247ms/epoch - 4ms/step
# Epoch 8/200
# 64/64 - 0s - loss: 0.0298 - val_loss: 0.0141 - 265ms/epoch - 4ms/step
# Epoch 9/200
# 64/64 - 0s - loss: 0.0289 - val_loss: 0.0109 - 244ms/epoch - 4ms/step
# Epoch 10/200
# 64/64 - 0s - loss: 0.0293 - val_loss: 0.0120 - 242ms/epoch - 4ms/step
# Epoch 11/200
# 64/64 - 0s - loss: 0.0290 - val_loss: 0.0115 - 241ms/epoch - 4ms/step
# Epoch 12/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0107 - 272ms/epoch - 4ms/step
# Epoch 13/200
# 64/64 - 0s - loss: 0.0287 - val_loss: 0.0105 - 336ms/epoch - 5ms/step
# Epoch 14/200
# 64/64 - 0s - loss: 0.0290 - val_loss: 0.0103 - 466ms/epoch - 7ms/step
# Epoch 15/200
# 64/64 - 0s - loss: 0.0286 - val_loss: 0.0112 - 396ms/epoch - 6ms/step
# Epoch 16/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0095 - 382ms/epoch - 6ms/step
# Epoch 17/200
# 64/64 - 0s - loss: 0.0293 - val_loss: 0.0103 - 395ms/epoch - 6ms/step
# Epoch 18/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0092 - 407ms/epoch - 6ms/step
# Epoch 19/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0092 - 470ms/epoch - 7ms/step
# Epoch 20/200
# 64/64 - 0s - loss: 0.0283 - val_loss: 0.0097 - 443ms/epoch - 7ms/step
# Epoch 21/200
# 64/64 - 0s - loss: 0.0286 - val_loss: 0.0098 - 281ms/epoch - 4ms/step
# Epoch 22/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0095 - 261ms/epoch - 4ms/step
# Epoch 23/200
# 64/64 - 0s - loss: 0.0292 - val_loss: 0.0094 - 273ms/epoch - 4ms/step
# Epoch 24/200
# 64/64 - 0s - loss: 0.0289 - val_loss: 0.0091 - 274ms/epoch - 4ms/step
# Epoch 25/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0099 - 231ms/epoch - 4ms/step
# Epoch 26/200
# 64/64 - 0s - loss: 0.0277 - val_loss: 0.0093 - 240ms/epoch - 4ms/step
# Epoch 27/200
# 64/64 - 0s - loss: 0.0290 - val_loss: 0.0093 - 271ms/epoch - 4ms/step
# Epoch 28/200
# 64/64 - 0s - loss: 0.0283 - val_loss: 0.0093 - 252ms/epoch - 4ms/step
# Epoch 29/200
# 64/64 - 0s - loss: 0.0283 - val_loss: 0.0091 - 244ms/epoch - 4ms/step
# Epoch 30/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0096 - 262ms/epoch - 4ms/step
# Epoch 31/200
# 64/64 - 0s - loss: 0.0279 - val_loss: 0.0118 - 264ms/epoch - 4ms/step
# Epoch 32/200
# 64/64 - 0s - loss: 0.0295 - val_loss: 0.0101 - 272ms/epoch - 4ms/step
# Epoch 33/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0101 - 240ms/epoch - 4ms/step
# Epoch 34/200
# 64/64 - 0s - loss: 0.0286 - val_loss: 0.0094 - 242ms/epoch - 4ms/step
# Epoch 35/200
# 64/64 - 0s - loss: 0.0289 - val_loss: 0.0092 - 274ms/epoch - 4ms/step
# Epoch 36/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0092 - 253ms/epoch - 4ms/step
# Epoch 37/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0099 - 268ms/epoch - 4ms/step
# Epoch 38/200
# 64/64 - 0s - loss: 0.0280 - val_loss: 0.0098 - 238ms/epoch - 4ms/step
# Epoch 39/200
# 64/64 - 0s - loss: 0.0303 - val_loss: 0.0090 - 276ms/epoch - 4ms/step
# Epoch 40/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0093 - 249ms/epoch - 4ms/step
# Epoch 41/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0098 - 256ms/epoch - 4ms/step
# Epoch 42/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0111 - 257ms/epoch - 4ms/step
# Epoch 43/200
# 64/64 - 0s - loss: 0.0280 - val_loss: 0.0101 - 282ms/epoch - 4ms/step
# Epoch 44/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0090 - 263ms/epoch - 4ms/step
# Epoch 45/200
# 64/64 - 0s - loss: 0.0279 - val_loss: 0.0102 - 266ms/epoch - 4ms/step
# Epoch 46/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0092 - 282ms/epoch - 4ms/step
# Epoch 47/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0122 - 277ms/epoch - 4ms/step
# Epoch 48/200
# 64/64 - 0s - loss: 0.0287 - val_loss: 0.0096 - 271ms/epoch - 4ms/step
# Epoch 49/200
# 64/64 - 0s - loss: 0.0279 - val_loss: 0.0109 - 259ms/epoch - 4ms/step
# Epoch 50/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0092 - 291ms/epoch - 5ms/step
# Epoch 51/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0102 - 277ms/epoch - 4ms/step
# Epoch 52/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0113 - 253ms/epoch - 4ms/step
# Epoch 53/200
# 64/64 - 0s - loss: 0.0291 - val_loss: 0.0098 - 266ms/epoch - 4ms/step
# Epoch 54/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0096 - 271ms/epoch - 4ms/step
# Epoch 55/200
# 64/64 - 0s - loss: 0.0277 - val_loss: 0.0107 - 246ms/epoch - 4ms/step
# Epoch 56/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0094 - 256ms/epoch - 4ms/step
# Epoch 57/200
# 64/64 - 0s - loss: 0.0290 - val_loss: 0.0090 - 251ms/epoch - 4ms/step
# Epoch 58/200
# 64/64 - 0s - loss: 0.0289 - val_loss: 0.0090 - 348ms/epoch - 5ms/step
# Epoch 59/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0091 - 453ms/epoch - 7ms/step
# Epoch 60/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0092 - 455ms/epoch - 7ms/step
# Epoch 61/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0091 - 476ms/epoch - 7ms/step
# Epoch 62/200
# 64/64 - 0s - loss: 0.0280 - val_loss: 0.0091 - 457ms/epoch - 7ms/step
# Epoch 63/200
# 64/64 - 0s - loss: 0.0279 - val_loss: 0.0094 - 490ms/epoch - 8ms/step
# Epoch 64/200
# 64/64 - 1s - loss: 0.0291 - val_loss: 0.0090 - 518ms/epoch - 8ms/step
# Epoch 65/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0097 - 304ms/epoch - 5ms/step
# Epoch 66/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0103 - 281ms/epoch - 4ms/step
# Epoch 67/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0120 - 258ms/epoch - 4ms/step
# Epoch 68/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0095 - 346ms/epoch - 5ms/step
# Epoch 69/200
# 64/64 - 0s - loss: 0.0276 - val_loss: 0.0093 - 260ms/epoch - 4ms/step
# Epoch 70/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0107 - 282ms/epoch - 4ms/step
# Epoch 71/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0102 - 286ms/epoch - 4ms/step
# Epoch 72/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0098 - 268ms/epoch - 4ms/step
# Epoch 73/200
# 64/64 - 0s - loss: 0.0286 - val_loss: 0.0102 - 259ms/epoch - 4ms/step
# Epoch 74/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0103 - 262ms/epoch - 4ms/step
# Epoch 75/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0094 - 270ms/epoch - 4ms/step
# Epoch 76/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0093 - 287ms/epoch - 4ms/step
# Epoch 77/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0090 - 262ms/epoch - 4ms/step
# Epoch 78/200
# 64/64 - 0s - loss: 0.0284 - val_loss: 0.0093 - 266ms/epoch - 4ms/step
# Epoch 79/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0104 - 274ms/epoch - 4ms/step
# Epoch 80/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0096 - 250ms/epoch - 4ms/step
# Epoch 81/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0095 - 258ms/epoch - 4ms/step
# Epoch 82/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0102 - 261ms/epoch - 4ms/step
# Epoch 83/200
# 64/64 - 0s - loss: 0.0280 - val_loss: 0.0101 - 258ms/epoch - 4ms/step
# Epoch 84/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0105 - 251ms/epoch - 4ms/step
# Epoch 85/200
# 64/64 - 0s - loss: 0.0288 - val_loss: 0.0093 - 255ms/epoch - 4ms/step
# Epoch 86/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0109 - 268ms/epoch - 4ms/step
# Epoch 87/200
# 64/64 - 0s - loss: 0.0280 - val_loss: 0.0094 - 255ms/epoch - 4ms/step
# Epoch 88/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0091 - 229ms/epoch - 4ms/step
# Epoch 89/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0094 - 252ms/epoch - 4ms/step
# Epoch 90/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0113 - 280ms/epoch - 4ms/step
# Epoch 91/200
# 64/64 - 0s - loss: 0.0277 - val_loss: 0.0099 - 271ms/epoch - 4ms/step
# Epoch 92/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0100 - 256ms/epoch - 4ms/step
# Epoch 93/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0092 - 280ms/epoch - 4ms/step
# Epoch 94/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0101 - 257ms/epoch - 4ms/step
# Epoch 95/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0105 - 260ms/epoch - 4ms/step
# Epoch 96/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0103 - 252ms/epoch - 4ms/step
# Epoch 97/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0106 - 265ms/epoch - 4ms/step
# Epoch 98/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0092 - 234ms/epoch - 4ms/step
# Epoch 99/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0102 - 265ms/epoch - 4ms/step
# Epoch 100/200
# 64/64 - 0s - loss: 0.0270 - val_loss: 0.0091 - 252ms/epoch - 4ms/step
# Epoch 101/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0107 - 344ms/epoch - 5ms/step
# Epoch 102/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0091 - 451ms/epoch - 7ms/step
# Epoch 103/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0093 - 430ms/epoch - 7ms/step
# Epoch 104/200
# 64/64 - 0s - loss: 0.0274 - val_loss: 0.0092 - 419ms/epoch - 7ms/step
# Epoch 105/200
# 64/64 - 0s - loss: 0.0274 - val_loss: 0.0091 - 484ms/epoch - 8ms/step
# Epoch 106/200
# 64/64 - 0s - loss: 0.0274 - val_loss: 0.0096 - 474ms/epoch - 7ms/step
# Epoch 107/200
# 64/64 - 0s - loss: 0.0267 - val_loss: 0.0097 - 484ms/epoch - 8ms/step
# Epoch 108/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0097 - 258ms/epoch - 4ms/step
# Epoch 109/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0091 - 244ms/epoch - 4ms/step
# Epoch 110/200
# 64/64 - 0s - loss: 0.0274 - val_loss: 0.0093 - 273ms/epoch - 4ms/step
# Epoch 111/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0092 - 257ms/epoch - 4ms/step
# Epoch 112/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0105 - 290ms/epoch - 5ms/step
# Epoch 113/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0095 - 288ms/epoch - 4ms/step
# Epoch 114/200
# 64/64 - 0s - loss: 0.0276 - val_loss: 0.0094 - 302ms/epoch - 5ms/step
# Epoch 115/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0122 - 311ms/epoch - 5ms/step
# Epoch 116/200
# 64/64 - 0s - loss: 0.0278 - val_loss: 0.0109 - 289ms/epoch - 5ms/step
# Epoch 117/200
# 64/64 - 0s - loss: 0.0270 - val_loss: 0.0107 - 278ms/epoch - 4ms/step
# Epoch 118/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0091 - 303ms/epoch - 5ms/step
# Epoch 119/200
# 64/64 - 0s - loss: 0.0276 - val_loss: 0.0092 - 283ms/epoch - 4ms/step
# Epoch 120/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0098 - 242ms/epoch - 4ms/step
# Epoch 121/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0102 - 277ms/epoch - 4ms/step
# Epoch 122/200
# 64/64 - 0s - loss: 0.0276 - val_loss: 0.0129 - 270ms/epoch - 4ms/step
# Epoch 123/200
# 64/64 - 0s - loss: 0.0282 - val_loss: 0.0120 - 267ms/epoch - 4ms/step
# Epoch 124/200
# 64/64 - 0s - loss: 0.0285 - val_loss: 0.0096 - 246ms/epoch - 4ms/step
# Epoch 125/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0100 - 278ms/epoch - 4ms/step
# Epoch 126/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0106 - 263ms/epoch - 4ms/step
# Epoch 127/200
# 64/64 - 0s - loss: 0.0266 - val_loss: 0.0094 - 266ms/epoch - 4ms/step
# Epoch 128/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0097 - 301ms/epoch - 5ms/step
# Epoch 129/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0102 - 285ms/epoch - 4ms/step
# Epoch 130/200
# 64/64 - 0s - loss: 0.0270 - val_loss: 0.0096 - 282ms/epoch - 4ms/step
# Epoch 131/200
# 64/64 - 0s - loss: 0.0274 - val_loss: 0.0093 - 250ms/epoch - 4ms/step
# Epoch 132/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0106 - 266ms/epoch - 4ms/step
# Epoch 133/200
# 64/64 - 0s - loss: 0.0281 - val_loss: 0.0104 - 276ms/epoch - 4ms/step
# Epoch 134/200
# 64/64 - 0s - loss: 0.0270 - val_loss: 0.0097 - 280ms/epoch - 4ms/step
# Epoch 135/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0093 - 261ms/epoch - 4ms/step
# Epoch 136/200
# 64/64 - 0s - loss: 0.0276 - val_loss: 0.0091 - 292ms/epoch - 5ms/step
# Epoch 137/200
# 64/64 - 0s - loss: 0.0267 - val_loss: 0.0099 - 275ms/epoch - 4ms/step
# Epoch 138/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0092 - 269ms/epoch - 4ms/step
# Epoch 139/200
# 64/64 - 0s - loss: 0.0277 - val_loss: 0.0110 - 265ms/epoch - 4ms/step
# Epoch 140/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0102 - 296ms/epoch - 5ms/step
# Epoch 141/200
# 64/64 - 0s - loss: 0.0276 - val_loss: 0.0117 - 250ms/epoch - 4ms/step
# Epoch 142/200
# 64/64 - 0s - loss: 0.0265 - val_loss: 0.0098 - 257ms/epoch - 4ms/step
# Epoch 143/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0094 - 353ms/epoch - 6ms/step
# Epoch 144/200
# 64/64 - 0s - loss: 0.0263 - val_loss: 0.0103 - 452ms/epoch - 7ms/step
# Epoch 145/200
# 64/64 - 0s - loss: 0.0264 - val_loss: 0.0095 - 393ms/epoch - 6ms/step
# Epoch 146/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0103 - 453ms/epoch - 7ms/step
# Epoch 147/200
# 64/64 - 0s - loss: 0.0264 - val_loss: 0.0099 - 444ms/epoch - 7ms/step
# Epoch 148/200
# 64/64 - 0s - loss: 0.0263 - val_loss: 0.0094 - 467ms/epoch - 7ms/step
# Epoch 149/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0109 - 385ms/epoch - 6ms/step
# Epoch 150/200
# 64/64 - 0s - loss: 0.0265 - val_loss: 0.0109 - 483ms/epoch - 8ms/step
# Epoch 151/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0106 - 297ms/epoch - 5ms/step
# Epoch 152/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0096 - 261ms/epoch - 4ms/step
# Epoch 153/200
# 64/64 - 0s - loss: 0.0265 - val_loss: 0.0097 - 286ms/epoch - 4ms/step
# Epoch 154/200
# 64/64 - 0s - loss: 0.0265 - val_loss: 0.0101 - 276ms/epoch - 4ms/step
# Epoch 155/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0092 - 264ms/epoch - 4ms/step
# Epoch 156/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0096 - 263ms/epoch - 4ms/step
# Epoch 157/200
# 64/64 - 0s - loss: 0.0264 - val_loss: 0.0096 - 266ms/epoch - 4ms/step
# Epoch 158/200
# 64/64 - 0s - loss: 0.0270 - val_loss: 0.0092 - 252ms/epoch - 4ms/step
# Epoch 159/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0101 - 258ms/epoch - 4ms/step
# Epoch 160/200
# 64/64 - 0s - loss: 0.0262 - val_loss: 0.0094 - 253ms/epoch - 4ms/step
# Epoch 161/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0095 - 294ms/epoch - 5ms/step
# Epoch 162/200
# 64/64 - 0s - loss: 0.0263 - val_loss: 0.0102 - 296ms/epoch - 5ms/step
# Epoch 163/200
# 64/64 - 0s - loss: 0.0264 - val_loss: 0.0111 - 264ms/epoch - 4ms/step
# Epoch 164/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0098 - 287ms/epoch - 4ms/step
# Epoch 165/200
# 64/64 - 0s - loss: 0.0272 - val_loss: 0.0096 - 286ms/epoch - 4ms/step
# Epoch 166/200
# 64/64 - 0s - loss: 0.0266 - val_loss: 0.0102 - 275ms/epoch - 4ms/step
# Epoch 167/200
# 64/64 - 0s - loss: 0.0265 - val_loss: 0.0121 - 255ms/epoch - 4ms/step
# Epoch 168/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0094 - 262ms/epoch - 4ms/step
# Epoch 169/200
# 64/64 - 0s - loss: 0.0265 - val_loss: 0.0097 - 294ms/epoch - 5ms/step
# Epoch 170/200
# 64/64 - 0s - loss: 0.0263 - val_loss: 0.0113 - 250ms/epoch - 4ms/step
# Epoch 171/200
# 64/64 - 0s - loss: 0.0270 - val_loss: 0.0095 - 249ms/epoch - 4ms/step
# Epoch 172/200
# 64/64 - 0s - loss: 0.0266 - val_loss: 0.0097 - 281ms/epoch - 4ms/step
# Epoch 173/200
# 64/64 - 0s - loss: 0.0267 - val_loss: 0.0103 - 256ms/epoch - 4ms/step
# Epoch 174/200
# 64/64 - 0s - loss: 0.0260 - val_loss: 0.0094 - 236ms/epoch - 4ms/step
# Epoch 175/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0101 - 269ms/epoch - 4ms/step
# Epoch 176/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0122 - 276ms/epoch - 4ms/step
# Epoch 177/200
# 64/64 - 0s - loss: 0.0263 - val_loss: 0.0093 - 269ms/epoch - 4ms/step
# Epoch 178/200
# 64/64 - 0s - loss: 0.0275 - val_loss: 0.0098 - 254ms/epoch - 4ms/step
# Epoch 179/200
# 64/64 - 0s - loss: 0.0265 - val_loss: 0.0098 - 278ms/epoch - 4ms/step
# Epoch 180/200
# 64/64 - 0s - loss: 0.0269 - val_loss: 0.0093 - 270ms/epoch - 4ms/step
# Epoch 181/200
# 64/64 - 0s - loss: 0.0268 - val_loss: 0.0095 - 271ms/epoch - 4ms/step
# Epoch 182/200
# 64/64 - 0s - loss: 0.0263 - val_loss: 0.0097 - 258ms/epoch - 4ms/step
# Epoch 183/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0095 - 273ms/epoch - 4ms/step
# Epoch 184/200
# 64/64 - 0s - loss: 0.0266 - val_loss: 0.0094 - 267ms/epoch - 4ms/step
# Epoch 185/200
# 64/64 - 0s - loss: 0.0264 - val_loss: 0.0104 - 264ms/epoch - 4ms/step
# Epoch 186/200
# 64/64 - 0s - loss: 0.0262 - val_loss: 0.0106 - 259ms/epoch - 4ms/step
# Epoch 187/200
# 64/64 - 0s - loss: 0.0267 - val_loss: 0.0095 - 266ms/epoch - 4ms/step
# Epoch 188/200
# 64/64 - 0s - loss: 0.0273 - val_loss: 0.0093 - 475ms/epoch - 7ms/step
# Epoch 189/200
# 64/64 - 0s - loss: 0.0266 - val_loss: 0.0108 - 408ms/epoch - 6ms/step
# Epoch 190/200
# 64/64 - 0s - loss: 0.0266 - val_loss: 0.0097 - 370ms/epoch - 6ms/step
# Epoch 191/200
# 64/64 - 0s - loss: 0.0264 - val_loss: 0.0105 - 455ms/epoch - 7ms/step
# Epoch 192/200
# 64/64 - 0s - loss: 0.0261 - val_loss: 0.0105 - 457ms/epoch - 7ms/step
# Epoch 193/200
# 64/64 - 0s - loss: 0.0262 - val_loss: 0.0110 - 492ms/epoch - 8ms/step
# Epoch 194/200
# 64/64 - 0s - loss: 0.0267 - val_loss: 0.0109 - 433ms/epoch - 7ms/step
# Epoch 195/200
# 64/64 - 0s - loss: 0.0264 - val_loss: 0.0115 - 271ms/epoch - 4ms/step
# Epoch 196/200
# 64/64 - 0s - loss: 0.0261 - val_loss: 0.0097 - 276ms/epoch - 4ms/step
# Epoch 197/200
# 64/64 - 0s - loss: 0.0262 - val_loss: 0.0099 - 277ms/epoch - 4ms/step
# Epoch 198/200
# 64/64 - 0s - loss: 0.0261 - val_loss: 0.0103 - 260ms/epoch - 4ms/step
# Epoch 199/200
# 64/64 - 0s - loss: 0.0271 - val_loss: 0.0098 - 282ms/epoch - 4ms/step
# Epoch 200/200
# 64/64 - 0s - loss: 0.0263 - val_loss: 0.0101 - 286ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 7ms/step
# 1/1 [==============================] - 1s 680ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# بستن تمام پنجره‌های نمودار باز
plt.close('all')

# بارگذاری داده‌ها از فایل CSV
df = pd.read_csv('example1.csv')

# دریافت لیست نام ستون‌ها
df_columns = list(df.columns)

# انتخاب ستون مورد نظر برای نمایش داده‌ها
selected_column = df_columns[5]

# انتخاب 100 داده اول از ستون مورد نظر
data_to_plot = df[selected_column][:99].values.reshape(-1,1)  # تبدیل به آرایه دو بعدی برای مقیاس‌بندی

# مقیاس‌بندی داده‌ها
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_to_plot)

# تقسیم داده‌ها به دو بخش آموزشی و تست
train_size = int(len(scaled_data) * 0.67)
test_size = len(scaled_data) - train_size
train, test = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# تابع برای ایجاد داده‌های آموزشی
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# ایجاد داده‌های آموزشی و تست
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# تغییر شکل ورودی‌ها برای LSTM
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# ایجاد و آموزش شبکه LSTM
model = Sequential()
model.add(LSTM(100, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2, validation_data=(testX, testY))

# پیش‌بینی‌ها
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# تبدیل پیش‌بینی‌ها به مقیاس اصلی
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# تعداد نقاط داده‌ای که می‌خواهیم پیش‌بینی کنیم
num_future_points = 20

# آخرین نقطه داده‌ای از مجموعه داده‌های آموزشی
last_point = trainX[-1]

# لیست برای نگهداری پیش‌بینی‌های آینده
future_predictions = []

# حلقه برای پیش‌بینی نقاط داده‌های آینده
for _ in range(num_future_points):
    # پیش‌بینی با استفاده از آخرین نقطه داده‌ای
    prediction = model.predict(last_point.reshape(1, 1, look_back))

    # اضافه کردن پیش‌بینی به لیست
    future_predictions.append(prediction[0,0])

    # به‌روزرسانی آخرین نقطه داده‌ای با استفاده از پیش‌بینی جدید
    last_point = np.roll(last_point, -1)
    last_point[-1] = prediction

# تبدیل پیش‌بینی‌های آینده به مقیاس اصلی
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# نمایش نمودارها
plt.figure(figsize=(10, 5))
plt.plot(trainY[0], label='Actual')
plt.plot(trainPredict[:,0], label='Predicted')
plt.title('Mohammad Mohammadi show the answer \n Train Data vs Predicted Data \n NOx ')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(testY[0], label='Actual')
plt.plot(testPredict[:,0], label='Predicted')
plt.title('Test Data vs Predicted Data \n NOx')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()



# اضافه کردن پیش‌بینی‌های آینده به نمودار
plt.figure(figsize=(10, 5))
plt.plot(range(len(trainY[0])), trainY[0], label='Actual')
plt.plot(range(len(trainPredict[:,0])), trainPredict[:,0], label='Predicted')
plt.plot(range(len(trainY[0]), len(trainY[0])+num_future_points), future_predictions[:,0], label='Future Predicted')
plt.title('Train Data vs Predicted Data vs Future Predicted Data \n NOx')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 64/64 - 3s - loss: 0.0047 - val_loss: 0.1025 - 3s/epoch - 43ms/step
# Epoch 2/200
# 64/64 - 0s - loss: 0.0032 - val_loss: 0.0877 - 252ms/epoch - 4ms/step
# Epoch 3/200
# 64/64 - 0s - loss: 0.0027 - val_loss: 0.0727 - 259ms/epoch - 4ms/step
# Epoch 4/200
# 64/64 - 0s - loss: 0.0025 - val_loss: 0.0628 - 261ms/epoch - 4ms/step
# Epoch 5/200
# 64/64 - 0s - loss: 0.0019 - val_loss: 0.0466 - 271ms/epoch - 4ms/step
# Epoch 6/200
# 64/64 - 0s - loss: 0.0017 - val_loss: 0.0303 - 275ms/epoch - 4ms/step
# Epoch 7/200
# 64/64 - 0s - loss: 0.0015 - val_loss: 0.0293 - 257ms/epoch - 4ms/step
# Epoch 8/200
# 64/64 - 0s - loss: 0.0012 - val_loss: 0.0210 - 255ms/epoch - 4ms/step
# Epoch 9/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0160 - 258ms/epoch - 4ms/step
# Epoch 10/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0144 - 271ms/epoch - 4ms/step
# Epoch 11/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0113 - 264ms/epoch - 4ms/step
# Epoch 12/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0114 - 272ms/epoch - 4ms/step
# Epoch 13/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0109 - 253ms/epoch - 4ms/step
# Epoch 14/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0113 - 273ms/epoch - 4ms/step
# Epoch 15/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0105 - 233ms/epoch - 4ms/step
# Epoch 16/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0090 - 248ms/epoch - 4ms/step
# Epoch 17/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0103 - 268ms/epoch - 4ms/step
# Epoch 18/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0111 - 480ms/epoch - 7ms/step
# Epoch 19/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0107 - 439ms/epoch - 7ms/step
# Epoch 20/200
# 64/64 - 0s - loss: 9.8707e-04 - val_loss: 0.0097 - 396ms/epoch - 6ms/step
# Epoch 21/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0120 - 464ms/epoch - 7ms/step
# Epoch 22/200
# 64/64 - 0s - loss: 9.8969e-04 - val_loss: 0.0115 - 426ms/epoch - 7ms/step
# Epoch 23/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0101 - 446ms/epoch - 7ms/step
# Epoch 24/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0093 - 492ms/epoch - 8ms/step
# Epoch 25/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0107 - 269ms/epoch - 4ms/step
# Epoch 26/200
# 64/64 - 0s - loss: 9.7532e-04 - val_loss: 0.0109 - 257ms/epoch - 4ms/step
# Epoch 27/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0145 - 269ms/epoch - 4ms/step
# Epoch 28/200
# 64/64 - 0s - loss: 0.0013 - val_loss: 0.0108 - 255ms/epoch - 4ms/step
# Epoch 29/200
# 64/64 - 0s - loss: 9.8823e-04 - val_loss: 0.0102 - 251ms/epoch - 4ms/step
# Epoch 30/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0106 - 259ms/epoch - 4ms/step
# Epoch 31/200
# 64/64 - 0s - loss: 9.9275e-04 - val_loss: 0.0099 - 288ms/epoch - 5ms/step
# Epoch 32/200
# 64/64 - 0s - loss: 9.7551e-04 - val_loss: 0.0119 - 263ms/epoch - 4ms/step
# Epoch 33/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0095 - 235ms/epoch - 4ms/step
# Epoch 34/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0096 - 239ms/epoch - 4ms/step
# Epoch 35/200
# 64/64 - 0s - loss: 9.4544e-04 - val_loss: 0.0132 - 295ms/epoch - 5ms/step
# Epoch 36/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0104 - 255ms/epoch - 4ms/step
# Epoch 37/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0115 - 242ms/epoch - 4ms/step
# Epoch 38/200
# 64/64 - 0s - loss: 0.0012 - val_loss: 0.0154 - 352ms/epoch - 6ms/step
# Epoch 39/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0150 - 263ms/epoch - 4ms/step
# Epoch 40/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0139 - 246ms/epoch - 4ms/step
# Epoch 41/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0120 - 238ms/epoch - 4ms/step
# Epoch 42/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0106 - 292ms/epoch - 5ms/step
# Epoch 43/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0111 - 246ms/epoch - 4ms/step
# Epoch 44/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0089 - 251ms/epoch - 4ms/step
# Epoch 45/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0113 - 242ms/epoch - 4ms/step
# Epoch 46/200
# 64/64 - 0s - loss: 9.9411e-04 - val_loss: 0.0095 - 271ms/epoch - 4ms/step
# Epoch 47/200
# 64/64 - 0s - loss: 9.6950e-04 - val_loss: 0.0091 - 240ms/epoch - 4ms/step
# Epoch 48/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0082 - 245ms/epoch - 4ms/step
# Epoch 49/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0115 - 258ms/epoch - 4ms/step
# Epoch 50/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0124 - 270ms/epoch - 4ms/step
# Epoch 51/200
# 64/64 - 0s - loss: 9.5385e-04 - val_loss: 0.0089 - 257ms/epoch - 4ms/step
# Epoch 52/200
# 64/64 - 0s - loss: 9.3841e-04 - val_loss: 0.0118 - 250ms/epoch - 4ms/step
# Epoch 53/200
# 64/64 - 0s - loss: 0.0012 - val_loss: 0.0099 - 229ms/epoch - 4ms/step
# Epoch 54/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0122 - 273ms/epoch - 4ms/step
# Epoch 55/200
# 64/64 - 0s - loss: 9.7817e-04 - val_loss: 0.0112 - 243ms/epoch - 4ms/step
# Epoch 56/200
# 64/64 - 0s - loss: 9.7667e-04 - val_loss: 0.0122 - 233ms/epoch - 4ms/step
# Epoch 57/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0097 - 234ms/epoch - 4ms/step
# Epoch 58/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0119 - 280ms/epoch - 4ms/step
# Epoch 59/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0105 - 233ms/epoch - 4ms/step
# Epoch 60/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0115 - 245ms/epoch - 4ms/step
# Epoch 61/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0107 - 230ms/epoch - 4ms/step
# Epoch 62/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0100 - 270ms/epoch - 4ms/step
# Epoch 63/200
# 64/64 - 0s - loss: 9.9684e-04 - val_loss: 0.0110 - 447ms/epoch - 7ms/step
# Epoch 64/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0097 - 391ms/epoch - 6ms/step
# Epoch 65/200
# 64/64 - 0s - loss: 9.7888e-04 - val_loss: 0.0109 - 463ms/epoch - 7ms/step
# Epoch 66/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0103 - 467ms/epoch - 7ms/step
# Epoch 67/200
# 64/64 - 0s - loss: 9.9937e-04 - val_loss: 0.0135 - 483ms/epoch - 8ms/step
# Epoch 68/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0106 - 453ms/epoch - 7ms/step
# Epoch 69/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0102 - 434ms/epoch - 7ms/step
# Epoch 70/200
# 64/64 - 0s - loss: 0.0013 - val_loss: 0.0133 - 261ms/epoch - 4ms/step
# Epoch 71/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0136 - 265ms/epoch - 4ms/step
# Epoch 72/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0114 - 261ms/epoch - 4ms/step
# Epoch 73/200
# 64/64 - 0s - loss: 9.8793e-04 - val_loss: 0.0097 - 284ms/epoch - 4ms/step
# Epoch 74/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0112 - 263ms/epoch - 4ms/step
# Epoch 75/200
# 64/64 - 0s - loss: 9.5696e-04 - val_loss: 0.0103 - 348ms/epoch - 5ms/step
# Epoch 76/200
# 64/64 - 0s - loss: 9.8169e-04 - val_loss: 0.0097 - 273ms/epoch - 4ms/step
# Epoch 77/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0102 - 284ms/epoch - 4ms/step
# Epoch 78/200
# 64/64 - 0s - loss: 0.0012 - val_loss: 0.0107 - 273ms/epoch - 4ms/step
# Epoch 79/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0107 - 266ms/epoch - 4ms/step
# Epoch 80/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0152 - 282ms/epoch - 4ms/step
# Epoch 81/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0113 - 259ms/epoch - 4ms/step
# Epoch 82/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0120 - 302ms/epoch - 5ms/step
# Epoch 83/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0135 - 263ms/epoch - 4ms/step
# Epoch 84/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0127 - 269ms/epoch - 4ms/step
# Epoch 85/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0131 - 262ms/epoch - 4ms/step
# Epoch 86/200
# 64/64 - 0s - loss: 9.7042e-04 - val_loss: 0.0134 - 274ms/epoch - 4ms/step
# Epoch 87/200
# 64/64 - 0s - loss: 9.8364e-04 - val_loss: 0.0102 - 268ms/epoch - 4ms/step
# Epoch 88/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0111 - 285ms/epoch - 4ms/step
# Epoch 89/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0120 - 260ms/epoch - 4ms/step
# Epoch 90/200
# 64/64 - 0s - loss: 9.9353e-04 - val_loss: 0.0136 - 245ms/epoch - 4ms/step
# Epoch 91/200
# 64/64 - 0s - loss: 9.9859e-04 - val_loss: 0.0131 - 253ms/epoch - 4ms/step
# Epoch 92/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0126 - 259ms/epoch - 4ms/step
# Epoch 93/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0124 - 258ms/epoch - 4ms/step
# Epoch 94/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0116 - 261ms/epoch - 4ms/step
# Epoch 95/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0107 - 284ms/epoch - 4ms/step
# Epoch 96/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0124 - 247ms/epoch - 4ms/step
# Epoch 97/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0125 - 268ms/epoch - 4ms/step
# Epoch 98/200
# 64/64 - 0s - loss: 9.9669e-04 - val_loss: 0.0122 - 257ms/epoch - 4ms/step
# Epoch 99/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0105 - 359ms/epoch - 6ms/step
# Epoch 100/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0131 - 277ms/epoch - 4ms/step
# Epoch 101/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0136 - 287ms/epoch - 4ms/step
# Epoch 102/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0116 - 251ms/epoch - 4ms/step
# Epoch 103/200
# 64/64 - 0s - loss: 9.4838e-04 - val_loss: 0.0116 - 257ms/epoch - 4ms/step
# Epoch 104/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0134 - 269ms/epoch - 4ms/step
# Epoch 105/200
# 64/64 - 0s - loss: 9.9195e-04 - val_loss: 0.0113 - 238ms/epoch - 4ms/step
# Epoch 106/200
# 64/64 - 0s - loss: 9.8600e-04 - val_loss: 0.0128 - 442ms/epoch - 7ms/step
# Epoch 107/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0121 - 419ms/epoch - 7ms/step
# Epoch 108/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0123 - 459ms/epoch - 7ms/step
# Epoch 109/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0139 - 462ms/epoch - 7ms/step
# Epoch 110/200
# 64/64 - 0s - loss: 9.2416e-04 - val_loss: 0.0095 - 457ms/epoch - 7ms/step
# Epoch 111/200
# 64/64 - 0s - loss: 0.0013 - val_loss: 0.0129 - 466ms/epoch - 7ms/step
# Epoch 112/200
# 64/64 - 0s - loss: 9.9408e-04 - val_loss: 0.0114 - 343ms/epoch - 5ms/step
# Epoch 113/200
# 64/64 - 0s - loss: 9.7988e-04 - val_loss: 0.0117 - 234ms/epoch - 4ms/step
# Epoch 114/200
# 64/64 - 0s - loss: 9.8905e-04 - val_loss: 0.0108 - 274ms/epoch - 4ms/step
# Epoch 115/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0123 - 263ms/epoch - 4ms/step
# Epoch 116/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0099 - 288ms/epoch - 5ms/step
# Epoch 117/200
# 64/64 - 0s - loss: 9.1197e-04 - val_loss: 0.0132 - 270ms/epoch - 4ms/step
# Epoch 118/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0114 - 286ms/epoch - 4ms/step
# Epoch 119/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0128 - 266ms/epoch - 4ms/step
# Epoch 120/200
# 64/64 - 0s - loss: 9.7919e-04 - val_loss: 0.0124 - 278ms/epoch - 4ms/step
# Epoch 121/200
# 64/64 - 0s - loss: 9.5948e-04 - val_loss: 0.0117 - 291ms/epoch - 5ms/step
# Epoch 122/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0128 - 305ms/epoch - 5ms/step
# Epoch 123/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0144 - 278ms/epoch - 4ms/step
# Epoch 124/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0123 - 278ms/epoch - 4ms/step
# Epoch 125/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0140 - 294ms/epoch - 5ms/step
# Epoch 126/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0135 - 288ms/epoch - 4ms/step
# Epoch 127/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0131 - 290ms/epoch - 5ms/step
# Epoch 128/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0124 - 281ms/epoch - 4ms/step
# Epoch 129/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0115 - 305ms/epoch - 5ms/step
# Epoch 130/200
# 64/64 - 0s - loss: 9.7374e-04 - val_loss: 0.0097 - 250ms/epoch - 4ms/step
# Epoch 131/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0137 - 253ms/epoch - 4ms/step
# Epoch 132/200
# 64/64 - 0s - loss: 0.0012 - val_loss: 0.0134 - 260ms/epoch - 4ms/step
# Epoch 133/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0148 - 283ms/epoch - 4ms/step
# Epoch 134/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0128 - 253ms/epoch - 4ms/step
# Epoch 135/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0116 - 258ms/epoch - 4ms/step
# Epoch 136/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0130 - 270ms/epoch - 4ms/step
# Epoch 137/200
# 64/64 - 0s - loss: 9.8051e-04 - val_loss: 0.0122 - 269ms/epoch - 4ms/step
# Epoch 138/200
# 64/64 - 0s - loss: 9.1924e-04 - val_loss: 0.0109 - 269ms/epoch - 4ms/step
# Epoch 139/200
# 64/64 - 0s - loss: 0.0013 - val_loss: 0.0143 - 267ms/epoch - 4ms/step
# Epoch 140/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0112 - 301ms/epoch - 5ms/step
# Epoch 141/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0139 - 264ms/epoch - 4ms/step
# Epoch 142/200
# 64/64 - 0s - loss: 9.1316e-04 - val_loss: 0.0102 - 255ms/epoch - 4ms/step
# Epoch 143/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0099 - 356ms/epoch - 6ms/step
# Epoch 144/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0123 - 279ms/epoch - 4ms/step
# Epoch 145/200
# 64/64 - 0s - loss: 9.6426e-04 - val_loss: 0.0144 - 270ms/epoch - 4ms/step
# Epoch 146/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0131 - 258ms/epoch - 4ms/step
# Epoch 147/200
# 64/64 - 0s - loss: 9.6782e-04 - val_loss: 0.0144 - 280ms/epoch - 4ms/step
# Epoch 148/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0130 - 403ms/epoch - 6ms/step
# Epoch 149/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0126 - 459ms/epoch - 7ms/step
# Epoch 150/200
# 64/64 - 0s - loss: 9.8284e-04 - val_loss: 0.0110 - 387ms/epoch - 6ms/step
# Epoch 151/200
# 64/64 - 0s - loss: 9.9003e-04 - val_loss: 0.0146 - 397ms/epoch - 6ms/step
# Epoch 152/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0150 - 477ms/epoch - 7ms/step
# Epoch 153/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0161 - 383ms/epoch - 6ms/step
# Epoch 154/200
# 64/64 - 0s - loss: 9.7563e-04 - val_loss: 0.0136 - 450ms/epoch - 7ms/step
# Epoch 155/200
# 64/64 - 0s - loss: 9.8387e-04 - val_loss: 0.0120 - 379ms/epoch - 6ms/step
# Epoch 156/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0126 - 227ms/epoch - 4ms/step
# Epoch 157/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0119 - 252ms/epoch - 4ms/step
# Epoch 158/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0150 - 255ms/epoch - 4ms/step
# Epoch 159/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0134 - 264ms/epoch - 4ms/step
# Epoch 160/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0131 - 243ms/epoch - 4ms/step
# Epoch 161/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0146 - 263ms/epoch - 4ms/step
# Epoch 162/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0127 - 290ms/epoch - 5ms/step
# Epoch 163/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0143 - 259ms/epoch - 4ms/step
# Epoch 164/200
# 64/64 - 0s - loss: 9.9080e-04 - val_loss: 0.0110 - 261ms/epoch - 4ms/step
# Epoch 165/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0131 - 284ms/epoch - 4ms/step
# Epoch 166/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0136 - 299ms/epoch - 5ms/step
# Epoch 167/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0110 - 300ms/epoch - 5ms/step
# Epoch 168/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0139 - 340ms/epoch - 5ms/step
# Epoch 169/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0132 - 407ms/epoch - 6ms/step
# Epoch 170/200
# 64/64 - 0s - loss: 9.6772e-04 - val_loss: 0.0122 - 282ms/epoch - 4ms/step
# Epoch 171/200
# 64/64 - 0s - loss: 9.9501e-04 - val_loss: 0.0132 - 273ms/epoch - 4ms/step
# Epoch 172/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0116 - 275ms/epoch - 4ms/step
# Epoch 173/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0138 - 280ms/epoch - 4ms/step
# Epoch 174/200
# 64/64 - 0s - loss: 9.6218e-04 - val_loss: 0.0125 - 246ms/epoch - 4ms/step
# Epoch 175/200
# 64/64 - 0s - loss: 9.9652e-04 - val_loss: 0.0159 - 290ms/epoch - 5ms/step
# Epoch 176/200
# 64/64 - 0s - loss: 9.7046e-04 - val_loss: 0.0114 - 358ms/epoch - 6ms/step
# Epoch 177/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0138 - 257ms/epoch - 4ms/step
# Epoch 178/200
# 64/64 - 0s - loss: 9.8126e-04 - val_loss: 0.0128 - 260ms/epoch - 4ms/step
# Epoch 179/200
# 64/64 - 0s - loss: 9.7561e-04 - val_loss: 0.0125 - 260ms/epoch - 4ms/step
# Epoch 180/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0159 - 279ms/epoch - 4ms/step
# Epoch 181/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0124 - 263ms/epoch - 4ms/step
# Epoch 182/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0145 - 286ms/epoch - 4ms/step
# Epoch 183/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0128 - 264ms/epoch - 4ms/step
# Epoch 184/200
# 64/64 - 0s - loss: 9.9734e-04 - val_loss: 0.0112 - 288ms/epoch - 5ms/step
# Epoch 185/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0131 - 352ms/epoch - 5ms/step
# Epoch 186/200
# 64/64 - 0s - loss: 9.6849e-04 - val_loss: 0.0139 - 271ms/epoch - 4ms/step
# Epoch 187/200
# 64/64 - 0s - loss: 9.9190e-04 - val_loss: 0.0116 - 272ms/epoch - 4ms/step
# Epoch 188/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0152 - 240ms/epoch - 4ms/step
# Epoch 189/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0149 - 241ms/epoch - 4ms/step
# Epoch 190/200
# 64/64 - 0s - loss: 0.0011 - val_loss: 0.0153 - 252ms/epoch - 4ms/step
# Epoch 191/200
# 64/64 - 0s - loss: 9.5601e-04 - val_loss: 0.0153 - 442ms/epoch - 7ms/step
# Epoch 192/200
# 64/64 - 0s - loss: 9.6432e-04 - val_loss: 0.0118 - 496ms/epoch - 8ms/step
# Epoch 193/200
# 64/64 - 0s - loss: 9.9150e-04 - val_loss: 0.0135 - 460ms/epoch - 7ms/step
# Epoch 194/200
# 64/64 - 0s - loss: 9.8454e-04 - val_loss: 0.0143 - 458ms/epoch - 7ms/step
# Epoch 195/200
# 64/64 - 0s - loss: 9.9706e-04 - val_loss: 0.0151 - 470ms/epoch - 7ms/step
# Epoch 196/200
# 64/64 - 0s - loss: 9.9308e-04 - val_loss: 0.0136 - 474ms/epoch - 7ms/step
# Epoch 197/200
# 64/64 - 0s - loss: 9.6862e-04 - val_loss: 0.0142 - 285ms/epoch - 4ms/step
# Epoch 198/200
# 64/64 - 0s - loss: 0.0010 - val_loss: 0.0136 - 252ms/epoch - 4ms/step
# Epoch 199/200
# 64/64 - 0s - loss: 9.6534e-04 - val_loss: 0.0120 - 262ms/epoch - 4ms/step
# Epoch 200/200
# 64/64 - 0s - loss: 9.8433e-04 - val_loss: 0.0149 - 252ms/epoch - 4ms/step
# 2/2 [==============================] - 1s 10ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
