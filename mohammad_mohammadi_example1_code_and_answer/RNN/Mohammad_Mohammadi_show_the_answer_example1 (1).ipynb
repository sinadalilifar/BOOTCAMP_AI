# %% [markdown]
# شبکه LSTM

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# بستن تمام پنجره‌های نمودار باز
plt.close('all')

# بارگذاری داده‌ها از فایل CSV
df = pd.read_csv('example1.csv')

# دریافت لیست نام ستون‌ها
df_columns = list(df.columns)

# انتخاب ستون مورد نظر برای نمایش داده‌ها
selected_column = df_columns[8]

# انتخاب 100 داده اول از ستون مورد نظر
data_to_plot = df[selected_column][:99].values.reshape(-1,1)  # تبدیل به آرایه دو بعدی برای مقیاس‌بندی

# مقیاس‌بندی داده‌ها
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_to_plot)

# تقسیم داده‌ها به دو بخش آموزشی و تست
train_size = int(len(scaled_data) * 0.67)
test_size = len(scaled_data) - train_size
train, test = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# تابع برای ایجاد داده‌های آموزشی
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# ایجاد داده‌های آموزشی و تست
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# تغییر شکل ورودی‌ها برای LSTM
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# ایجاد و آموزش شبکه LSTM
model = Sequential()
model.add(LSTM(100, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2, validation_data=(testX, testY))

# پیش‌بینی‌ها
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# تبدیل پیش‌بینی‌ها به مقیاس اصلی
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# تعداد نقاط داده‌ای که می‌خواهیم پیش‌بینی کنیم
num_future_points = 20

# آخرین نقطه داده‌ای از مجموعه داده‌های آموزشی
last_point = trainX[-1]

# لیست برای نگهداری پیش‌بینی‌های آینده
future_predictions = []

# حلقه برای پیش‌بینی نقاط داده‌های آینده
for _ in range(num_future_points):
    # پیش‌بینی با استفاده از آخرین نقطه داده‌ای
    prediction = model.predict(last_point.reshape(1, 1, look_back))

    # اضافه کردن پیش‌بینی به لیست
    future_predictions.append(prediction[0,0])

    # به‌روزرسانی آخرین نقطه داده‌ای با استفاده از پیش‌بینی جدید
    last_point = np.roll(last_point, -1)
    last_point[-1] = prediction

# تبدیل پیش‌بینی‌های آینده به مقیاس اصلی
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# نمایش نمودارها
plt.figure(figsize=(10, 5))
plt.plot(trainY[0], label='Actual')
plt.plot(trainPredict[:,0], label='Predicted')
plt.title('Mohammad Mohammadi show the answer \n Train Data vs Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(testY[0], label='Actual')
plt.plot(testPredict[:,0], label='Predicted')
plt.title('Test Data vs Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()



# اضافه کردن پیش‌بینی‌های آینده به نمودار
plt.figure(figsize=(10, 5))
plt.plot(range(len(trainY[0])), trainY[0], label='Actual')
plt.plot(range(len(trainPredict[:,0])), trainPredict[:,0], label='Predicted')
plt.plot(range(len(trainY[0]), len(trainY[0])+num_future_points), future_predictions[:,0], label='Future Predicted')
plt.title('Train Data vs Predicted Data vs Future Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()


# رسم مقادیر خطای آموزش و تست
plt.subplot(2,1,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/200
# 62/62 - 4s - loss: 0.0788 - val_loss: 0.0169 - 4s/epoch - 60ms/step
# Epoch 2/200
# 62/62 - 0s - loss: 0.0375 - val_loss: 0.0182 - 349ms/epoch - 6ms/step
# Epoch 3/200
# 62/62 - 0s - loss: 0.0353 - val_loss: 0.0158 - 282ms/epoch - 5ms/step
# Epoch 4/200
# 62/62 - 0s - loss: 0.0334 - val_loss: 0.0138 - 256ms/epoch - 4ms/step
# Epoch 5/200
# 62/62 - 0s - loss: 0.0318 - val_loss: 0.0134 - 245ms/epoch - 4ms/step
# Epoch 6/200
# 62/62 - 0s - loss: 0.0311 - val_loss: 0.0128 - 241ms/epoch - 4ms/step
# Epoch 7/200
# 62/62 - 0s - loss: 0.0301 - val_loss: 0.0134 - 257ms/epoch - 4ms/step
# Epoch 8/200
# 62/62 - 0s - loss: 0.0287 - val_loss: 0.0113 - 254ms/epoch - 4ms/step
# Epoch 9/200
# 62/62 - 0s - loss: 0.0283 - val_loss: 0.0117 - 233ms/epoch - 4ms/step
# Epoch 10/200
# 62/62 - 0s - loss: 0.0288 - val_loss: 0.0106 - 226ms/epoch - 4ms/step
# Epoch 11/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0108 - 262ms/epoch - 4ms/step
# Epoch 12/200
# 62/62 - 0s - loss: 0.0281 - val_loss: 0.0105 - 251ms/epoch - 4ms/step
# Epoch 13/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0110 - 243ms/epoch - 4ms/step
# Epoch 14/200
# 62/62 - 0s - loss: 0.0288 - val_loss: 0.0116 - 272ms/epoch - 4ms/step
# Epoch 15/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0109 - 260ms/epoch - 4ms/step
# Epoch 16/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0103 - 234ms/epoch - 4ms/step
# Epoch 17/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0107 - 241ms/epoch - 4ms/step
# Epoch 18/200
# 62/62 - 0s - loss: 0.0280 - val_loss: 0.0101 - 232ms/epoch - 4ms/step
# Epoch 19/200
# 62/62 - 0s - loss: 0.0273 - val_loss: 0.0106 - 256ms/epoch - 4ms/step
# Epoch 20/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0107 - 262ms/epoch - 4ms/step
# Epoch 21/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0103 - 251ms/epoch - 4ms/step
# Epoch 22/200
# 62/62 - 0s - loss: 0.0286 - val_loss: 0.0103 - 270ms/epoch - 4ms/step
# Epoch 23/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0104 - 278ms/epoch - 4ms/step
# Epoch 24/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0130 - 270ms/epoch - 4ms/step
# Epoch 25/200
# 62/62 - 0s - loss: 0.0279 - val_loss: 0.0108 - 244ms/epoch - 4ms/step
# Epoch 26/200
# 62/62 - 0s - loss: 0.0273 - val_loss: 0.0101 - 256ms/epoch - 4ms/step
# Epoch 27/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0109 - 290ms/epoch - 5ms/step
# Epoch 28/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0133 - 252ms/epoch - 4ms/step
# Epoch 29/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0101 - 253ms/epoch - 4ms/step
# Epoch 30/200
# 62/62 - 0s - loss: 0.0269 - val_loss: 0.0112 - 233ms/epoch - 4ms/step
# Epoch 31/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0104 - 268ms/epoch - 4ms/step
# Epoch 32/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0105 - 246ms/epoch - 4ms/step
# Epoch 33/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0111 - 246ms/epoch - 4ms/step
# Epoch 34/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0102 - 275ms/epoch - 4ms/step
# Epoch 35/200
# 62/62 - 0s - loss: 0.0277 - val_loss: 0.0105 - 254ms/epoch - 4ms/step
# Epoch 36/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0101 - 283ms/epoch - 5ms/step
# Epoch 37/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0116 - 280ms/epoch - 5ms/step
# Epoch 38/200
# 62/62 - 0s - loss: 0.0255 - val_loss: 0.0105 - 254ms/epoch - 4ms/step
# Epoch 39/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0106 - 292ms/epoch - 5ms/step
# Epoch 40/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0115 - 266ms/epoch - 4ms/step
# Epoch 41/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0102 - 392ms/epoch - 6ms/step
# Epoch 42/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0113 - 400ms/epoch - 6ms/step
# Epoch 43/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0120 - 420ms/epoch - 7ms/step
# Epoch 44/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0141 - 426ms/epoch - 7ms/step
# Epoch 45/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0101 - 365ms/epoch - 6ms/step
# Epoch 46/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0110 - 451ms/epoch - 7ms/step
# Epoch 47/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0120 - 457ms/epoch - 7ms/step
# Epoch 48/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0117 - 228ms/epoch - 4ms/step
# Epoch 49/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0115 - 238ms/epoch - 4ms/step
# Epoch 50/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0120 - 227ms/epoch - 4ms/step
# Epoch 51/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0115 - 261ms/epoch - 4ms/step
# Epoch 52/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0102 - 251ms/epoch - 4ms/step
# Epoch 53/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0110 - 261ms/epoch - 4ms/step
# Epoch 54/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0112 - 249ms/epoch - 4ms/step
# Epoch 55/200
# 62/62 - 0s - loss: 0.0277 - val_loss: 0.0128 - 242ms/epoch - 4ms/step
# Epoch 56/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0107 - 255ms/epoch - 4ms/step
# Epoch 57/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0105 - 257ms/epoch - 4ms/step
# Epoch 58/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0119 - 287ms/epoch - 5ms/step
# Epoch 59/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0110 - 246ms/epoch - 4ms/step
# Epoch 60/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0102 - 273ms/epoch - 4ms/step
# Epoch 61/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0127 - 255ms/epoch - 4ms/step
# Epoch 62/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0106 - 288ms/epoch - 5ms/step
# Epoch 63/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0106 - 250ms/epoch - 4ms/step
# Epoch 64/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0123 - 258ms/epoch - 4ms/step
# Epoch 65/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0109 - 249ms/epoch - 4ms/step
# Epoch 66/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0113 - 266ms/epoch - 4ms/step
# Epoch 67/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0108 - 239ms/epoch - 4ms/step
# Epoch 68/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0114 - 246ms/epoch - 4ms/step
# Epoch 69/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0121 - 260ms/epoch - 4ms/step
# Epoch 70/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0106 - 272ms/epoch - 4ms/step
# Epoch 71/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0120 - 239ms/epoch - 4ms/step
# Epoch 72/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0102 - 240ms/epoch - 4ms/step
# Epoch 73/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0115 - 214ms/epoch - 3ms/step
# Epoch 74/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0113 - 210ms/epoch - 3ms/step
# Epoch 75/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0131 - 225ms/epoch - 4ms/step
# Epoch 76/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0106 - 251ms/epoch - 4ms/step
# Epoch 77/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0111 - 243ms/epoch - 4ms/step
# Epoch 78/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0114 - 252ms/epoch - 4ms/step
# Epoch 79/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0114 - 252ms/epoch - 4ms/step
# Epoch 80/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0102 - 239ms/epoch - 4ms/step
# Epoch 81/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0119 - 254ms/epoch - 4ms/step
# Epoch 82/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0109 - 250ms/epoch - 4ms/step
# Epoch 83/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0130 - 236ms/epoch - 4ms/step
# Epoch 84/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0115 - 242ms/epoch - 4ms/step
# Epoch 85/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0104 - 245ms/epoch - 4ms/step
# Epoch 86/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0104 - 259ms/epoch - 4ms/step
# Epoch 87/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0111 - 337ms/epoch - 5ms/step
# Epoch 88/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0104 - 441ms/epoch - 7ms/step
# Epoch 89/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0109 - 417ms/epoch - 7ms/step
# Epoch 90/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0111 - 411ms/epoch - 7ms/step
# Epoch 91/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0113 - 453ms/epoch - 7ms/step
# Epoch 92/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0119 - 461ms/epoch - 7ms/step
# Epoch 93/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0110 - 455ms/epoch - 7ms/step
# Epoch 94/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0112 - 293ms/epoch - 5ms/step
# Epoch 95/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0109 - 221ms/epoch - 4ms/step
# Epoch 96/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0132 - 237ms/epoch - 4ms/step
# Epoch 97/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0117 - 258ms/epoch - 4ms/step
# Epoch 98/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0103 - 230ms/epoch - 4ms/step
# Epoch 99/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0114 - 269ms/epoch - 4ms/step
# Epoch 100/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0111 - 234ms/epoch - 4ms/step
# Epoch 101/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0118 - 240ms/epoch - 4ms/step
# Epoch 102/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0118 - 217ms/epoch - 3ms/step
# Epoch 103/200
# 62/62 - 0s - loss: 0.0255 - val_loss: 0.0107 - 233ms/epoch - 4ms/step
# Epoch 104/200
# 62/62 - 0s - loss: 0.0255 - val_loss: 0.0103 - 247ms/epoch - 4ms/step
# Epoch 105/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0108 - 261ms/epoch - 4ms/step
# Epoch 106/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0120 - 220ms/epoch - 4ms/step
# Epoch 107/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0131 - 254ms/epoch - 4ms/step
# Epoch 108/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0116 - 251ms/epoch - 4ms/step
# Epoch 109/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0108 - 268ms/epoch - 4ms/step
# Epoch 110/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0116 - 251ms/epoch - 4ms/step
# Epoch 111/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0120 - 260ms/epoch - 4ms/step
# Epoch 112/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0109 - 257ms/epoch - 4ms/step
# Epoch 113/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0106 - 248ms/epoch - 4ms/step
# Epoch 114/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0107 - 225ms/epoch - 4ms/step
# Epoch 115/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0125 - 269ms/epoch - 4ms/step
# Epoch 116/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0134 - 232ms/epoch - 4ms/step
# Epoch 117/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0118 - 271ms/epoch - 4ms/step
# Epoch 118/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0106 - 237ms/epoch - 4ms/step
# Epoch 119/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0108 - 256ms/epoch - 4ms/step
# Epoch 120/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0105 - 262ms/epoch - 4ms/step
# Epoch 121/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0120 - 245ms/epoch - 4ms/step
# Epoch 122/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0119 - 235ms/epoch - 4ms/step
# Epoch 123/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0117 - 243ms/epoch - 4ms/step
# Epoch 124/200
# 62/62 - 0s - loss: 0.0255 - val_loss: 0.0109 - 251ms/epoch - 4ms/step
# Epoch 125/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0129 - 245ms/epoch - 4ms/step
# Epoch 126/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0108 - 255ms/epoch - 4ms/step
# Epoch 127/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0109 - 259ms/epoch - 4ms/step
# Epoch 128/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0111 - 250ms/epoch - 4ms/step
# Epoch 129/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0104 - 247ms/epoch - 4ms/step
# Epoch 130/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0108 - 229ms/epoch - 4ms/step
# Epoch 131/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0118 - 251ms/epoch - 4ms/step
# Epoch 132/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0116 - 240ms/epoch - 4ms/step
# Epoch 133/200
# 62/62 - 0s - loss: 0.0244 - val_loss: 0.0105 - 270ms/epoch - 4ms/step
# Epoch 134/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0128 - 409ms/epoch - 7ms/step
# Epoch 135/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0108 - 376ms/epoch - 6ms/step
# Epoch 136/200
# 62/62 - 0s - loss: 0.0247 - val_loss: 0.0121 - 417ms/epoch - 7ms/step
# Epoch 137/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0104 - 436ms/epoch - 7ms/step
# Epoch 138/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0137 - 445ms/epoch - 7ms/step
# Epoch 139/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0108 - 434ms/epoch - 7ms/step
# Epoch 140/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0104 - 459ms/epoch - 7ms/step
# Epoch 141/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0118 - 338ms/epoch - 5ms/step
# Epoch 142/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0121 - 240ms/epoch - 4ms/step
# Epoch 143/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0110 - 282ms/epoch - 5ms/step
# Epoch 144/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0135 - 236ms/epoch - 4ms/step
# Epoch 145/200
# 62/62 - 0s - loss: 0.0244 - val_loss: 0.0105 - 263ms/epoch - 4ms/step
# Epoch 146/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0106 - 279ms/epoch - 5ms/step
# Epoch 147/200
# 62/62 - 0s - loss: 0.0255 - val_loss: 0.0106 - 258ms/epoch - 4ms/step
# Epoch 148/200
# 62/62 - 0s - loss: 0.0255 - val_loss: 0.0112 - 267ms/epoch - 4ms/step
# Epoch 149/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0122 - 249ms/epoch - 4ms/step
# Epoch 150/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0127 - 255ms/epoch - 4ms/step
# Epoch 151/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0116 - 266ms/epoch - 4ms/step
# Epoch 152/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0106 - 255ms/epoch - 4ms/step
# Epoch 153/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0121 - 264ms/epoch - 4ms/step
# Epoch 154/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0105 - 260ms/epoch - 4ms/step
# Epoch 155/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0105 - 263ms/epoch - 4ms/step
# Epoch 156/200
# 62/62 - 0s - loss: 0.0243 - val_loss: 0.0120 - 251ms/epoch - 4ms/step
# Epoch 157/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0108 - 231ms/epoch - 4ms/step
# Epoch 158/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0118 - 240ms/epoch - 4ms/step
# Epoch 159/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0128 - 269ms/epoch - 4ms/step
# Epoch 160/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0121 - 235ms/epoch - 4ms/step
# Epoch 161/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0109 - 239ms/epoch - 4ms/step
# Epoch 162/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0117 - 236ms/epoch - 4ms/step
# Epoch 163/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0117 - 227ms/epoch - 4ms/step
# Epoch 164/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0109 - 219ms/epoch - 4ms/step
# Epoch 165/200
# 62/62 - 0s - loss: 0.0247 - val_loss: 0.0134 - 238ms/epoch - 4ms/step
# Epoch 166/200
# 62/62 - 0s - loss: 0.0247 - val_loss: 0.0109 - 235ms/epoch - 4ms/step
# Epoch 167/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0106 - 274ms/epoch - 4ms/step
# Epoch 168/200
# 62/62 - 0s - loss: 0.0247 - val_loss: 0.0111 - 235ms/epoch - 4ms/step
# Epoch 169/200
# 62/62 - 0s - loss: 0.0246 - val_loss: 0.0120 - 262ms/epoch - 4ms/step
# Epoch 170/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0115 - 283ms/epoch - 5ms/step
# Epoch 171/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0114 - 283ms/epoch - 5ms/step
# Epoch 172/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0111 - 251ms/epoch - 4ms/step
# Epoch 173/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0117 - 232ms/epoch - 4ms/step
# Epoch 174/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0129 - 249ms/epoch - 4ms/step
# Epoch 175/200
# 62/62 - 0s - loss: 0.0242 - val_loss: 0.0108 - 285ms/epoch - 5ms/step
# Epoch 176/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0108 - 266ms/epoch - 4ms/step
# Epoch 177/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0115 - 279ms/epoch - 4ms/step
# Epoch 178/200
# 62/62 - 0s - loss: 0.0247 - val_loss: 0.0114 - 283ms/epoch - 5ms/step
# Epoch 179/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0111 - 266ms/epoch - 4ms/step
# Epoch 180/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0124 - 446ms/epoch - 7ms/step
# Epoch 181/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0124 - 479ms/epoch - 8ms/step
# Epoch 182/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0110 - 452ms/epoch - 7ms/step
# Epoch 183/200
# 62/62 - 0s - loss: 0.0245 - val_loss: 0.0112 - 459ms/epoch - 7ms/step
# Epoch 184/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0115 - 488ms/epoch - 8ms/step
# Epoch 185/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0120 - 373ms/epoch - 6ms/step
# Epoch 186/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0135 - 458ms/epoch - 7ms/step
# Epoch 187/200
# 62/62 - 0s - loss: 0.0241 - val_loss: 0.0106 - 317ms/epoch - 5ms/step
# Epoch 188/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0141 - 268ms/epoch - 4ms/step
# Epoch 189/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0110 - 333ms/epoch - 5ms/step
# Epoch 190/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0112 - 270ms/epoch - 4ms/step
# Epoch 191/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0106 - 263ms/epoch - 4ms/step
# Epoch 192/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0112 - 264ms/epoch - 4ms/step
# Epoch 193/200
# 62/62 - 0s - loss: 0.0247 - val_loss: 0.0119 - 271ms/epoch - 4ms/step
# Epoch 194/200
# 62/62 - 0s - loss: 0.0248 - val_loss: 0.0126 - 269ms/epoch - 4ms/step
# Epoch 195/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0127 - 267ms/epoch - 4ms/step
# Epoch 196/200
# 62/62 - 0s - loss: 0.0247 - val_loss: 0.0113 - 269ms/epoch - 4ms/step
# Epoch 197/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0108 - 282ms/epoch - 5ms/step
# Epoch 198/200
# 62/62 - 0s - loss: 0.0251 - val_loss: 0.0111 - 274ms/epoch - 4ms/step
# Epoch 199/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0130 - 262ms/epoch - 4ms/step
# Epoch 200/200
# 62/62 - 0s - loss: 0.0252 - val_loss: 0.0126 - 248ms/epoch - 4ms/step
# 2/2 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# شبکه RNN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

# بستن تمام پنجره‌های نمودار باز
plt.close('all')

# بارگذاری داده‌ها از فایل CSV
df = pd.read_csv('example1.csv')

# دریافت لیست نام ستون‌ها
df_columns = list(df.columns)

# انتخاب ستون مورد نظر برای نمایش داده‌ها
selected_column = df_columns[8]

# انتخاب 100 داده اول از ستون مورد نظر
data_to_plot = df[selected_column][:99].values.reshape(-1,1)  # تبدیل به آرایه دو بعدی برای مقیاس‌بندی

# مقیاس‌بندی داده‌ها
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_to_plot)

# تقسیم داده‌ها به دو بخش آموزشی و تست
train_size = int(len(scaled_data) * 0.67)
test_size = len(scaled_data) - train_size
train, test = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# تابع برای ایجاد داده‌های آموزشی
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# ایجاد داده‌های آموزشی و تست
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# تغییر شکل ورودی‌ها برای RNN
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# ایجاد و آموزش شبکه RNN
model = Sequential()
model.add(SimpleRNN(100, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2, validation_data=(testX, testY))

# پیش‌بینی‌ها
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# تبدیل پیش‌بینی‌ها به مقیاس اصلی
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# تعداد نقاط داده‌ای که می‌خواهیم پیش‌بینی کنیم
num_future_points = 20

# آخرین نقطه داده‌ای از مجموعه داده‌های آموزشی
last_point = trainX[-1]

# لیست برای نگهداری پیش‌بینی‌های آینده
future_predictions = []

# حلقه برای پیش‌بینی نقاط داده‌های آینده
for _ in range(num_future_points):
    # پیش‌بینی با استفاده از آخرین نقطه داده‌ای
    prediction = model.predict(last_point.reshape(1, 1, look_back))

        # اضافه کردن پیش‌بینی به لیست
    future_predictions.append(prediction[0,0])

    # به‌روزرسانی آخرین نقطه داده‌ای با استفاده از پیش‌بینی جدید
    last_point = np.roll(last_point, -1)
    last_point[-1] = prediction

# تبدیل پیش‌بینی‌های آینده به مقیاس اصلی
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# نمایش نمودارها
plt.figure(figsize=(10, 5))
plt.plot(trainY[0], label='Actual')
plt.plot(trainPredict[:,0], label='Predicted')
plt.title('Train Data vs Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(testY[0], label='Actual')
plt.plot(testPredict[:,0], label='Predicted')
plt.title('Test Data vs Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# اضافه کردن پیش‌بینی‌های آینده به نمودار
plt.figure(figsize=(10, 5))
plt.plot(range(len(trainY[0])), trainY[0], label='Actual')
plt.plot(range(len(trainPredict[:,0])), trainPredict[:,0], label='Predicted')
plt.plot(range(len(trainY[0]), len(trainY[0])+num_future_points), future_predictions[:,0], label='Future Predicted')
plt.title('Train Data vs Predicted Data vs Future Predicted Data \n CO')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# رسم مقادیر خطای آموزش و تست
plt.subplot(2,1,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/200
# 62/62 - 1s - loss: 0.0433 - val_loss: 0.0119 - 1s/epoch - 20ms/step
# Epoch 2/200
# 62/62 - 0s - loss: 0.0303 - val_loss: 0.0170 - 155ms/epoch - 2ms/step
# Epoch 3/200
# 62/62 - 0s - loss: 0.0283 - val_loss: 0.0138 - 152ms/epoch - 2ms/step
# Epoch 4/200
# 62/62 - 0s - loss: 0.0278 - val_loss: 0.0118 - 179ms/epoch - 3ms/step
# Epoch 5/200
# 62/62 - 0s - loss: 0.0284 - val_loss: 0.0128 - 170ms/epoch - 3ms/step
# Epoch 6/200
# 62/62 - 0s - loss: 0.0273 - val_loss: 0.0143 - 177ms/epoch - 3ms/step
# Epoch 7/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0108 - 160ms/epoch - 3ms/step
# Epoch 8/200
# 62/62 - 0s - loss: 0.0281 - val_loss: 0.0112 - 159ms/epoch - 3ms/step
# Epoch 9/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0102 - 152ms/epoch - 2ms/step
# Epoch 10/200
# 62/62 - 0s - loss: 0.0325 - val_loss: 0.0107 - 180ms/epoch - 3ms/step
# Epoch 11/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0100 - 244ms/epoch - 4ms/step
# Epoch 12/200
# 62/62 - 0s - loss: 0.0278 - val_loss: 0.0140 - 237ms/epoch - 4ms/step
# Epoch 13/200
# 62/62 - 0s - loss: 0.0287 - val_loss: 0.0175 - 225ms/epoch - 4ms/step
# Epoch 14/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0102 - 239ms/epoch - 4ms/step
# Epoch 15/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0132 - 240ms/epoch - 4ms/step
# Epoch 16/200
# 62/62 - 0s - loss: 0.0274 - val_loss: 0.0110 - 215ms/epoch - 3ms/step
# Epoch 17/200
# 62/62 - 0s - loss: 0.0282 - val_loss: 0.0105 - 222ms/epoch - 4ms/step
# Epoch 18/200
# 62/62 - 0s - loss: 0.0311 - val_loss: 0.0106 - 242ms/epoch - 4ms/step
# Epoch 19/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0127 - 246ms/epoch - 4ms/step
# Epoch 20/200
# 62/62 - 0s - loss: 0.0284 - val_loss: 0.0102 - 231ms/epoch - 4ms/step
# Epoch 21/200
# 62/62 - 0s - loss: 0.0304 - val_loss: 0.0109 - 246ms/epoch - 4ms/step
# Epoch 22/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0114 - 320ms/epoch - 5ms/step
# Epoch 23/200
# 62/62 - 0s - loss: 0.0303 - val_loss: 0.0102 - 262ms/epoch - 4ms/step
# Epoch 24/200
# 62/62 - 0s - loss: 0.0288 - val_loss: 0.0105 - 155ms/epoch - 3ms/step
# Epoch 25/200
# 62/62 - 0s - loss: 0.0269 - val_loss: 0.0228 - 180ms/epoch - 3ms/step
# Epoch 26/200
# 62/62 - 0s - loss: 0.0332 - val_loss: 0.0119 - 178ms/epoch - 3ms/step
# Epoch 27/200
# 62/62 - 0s - loss: 0.0296 - val_loss: 0.0103 - 180ms/epoch - 3ms/step
# Epoch 28/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0163 - 164ms/epoch - 3ms/step
# Epoch 29/200
# 62/62 - 0s - loss: 0.0299 - val_loss: 0.0113 - 152ms/epoch - 2ms/step
# Epoch 30/200
# 62/62 - 0s - loss: 0.0278 - val_loss: 0.0106 - 153ms/epoch - 2ms/step
# Epoch 31/200
# 62/62 - 0s - loss: 0.0280 - val_loss: 0.0118 - 178ms/epoch - 3ms/step
# Epoch 32/200
# 62/62 - 0s - loss: 0.0287 - val_loss: 0.0125 - 179ms/epoch - 3ms/step
# Epoch 33/200
# 62/62 - 0s - loss: 0.0278 - val_loss: 0.0123 - 179ms/epoch - 3ms/step
# Epoch 34/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0108 - 170ms/epoch - 3ms/step
# Epoch 35/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0179 - 150ms/epoch - 2ms/step
# Epoch 36/200
# 62/62 - 0s - loss: 0.0312 - val_loss: 0.0113 - 152ms/epoch - 2ms/step
# Epoch 37/200
# 62/62 - 0s - loss: 0.0277 - val_loss: 0.0102 - 181ms/epoch - 3ms/step
# Epoch 38/200
# 62/62 - 0s - loss: 0.0295 - val_loss: 0.0111 - 179ms/epoch - 3ms/step
# Epoch 39/200
# 62/62 - 0s - loss: 0.0281 - val_loss: 0.0128 - 182ms/epoch - 3ms/step
# Epoch 40/200
# 62/62 - 0s - loss: 0.0303 - val_loss: 0.0135 - 187ms/epoch - 3ms/step
# Epoch 41/200
# 62/62 - 0s - loss: 0.0279 - val_loss: 0.0117 - 187ms/epoch - 3ms/step
# Epoch 42/200
# 62/62 - 0s - loss: 0.0249 - val_loss: 0.0167 - 157ms/epoch - 3ms/step
# Epoch 43/200
# 62/62 - 0s - loss: 0.0243 - val_loss: 0.0120 - 196ms/epoch - 3ms/step
# Epoch 44/200
# 62/62 - 0s - loss: 0.0303 - val_loss: 0.0123 - 176ms/epoch - 3ms/step
# Epoch 45/200
# 62/62 - 0s - loss: 0.0302 - val_loss: 0.0104 - 181ms/epoch - 3ms/step
# Epoch 46/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0102 - 152ms/epoch - 2ms/step
# Epoch 47/200
# 62/62 - 0s - loss: 0.0283 - val_loss: 0.0106 - 172ms/epoch - 3ms/step
# Epoch 48/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0106 - 149ms/epoch - 2ms/step
# Epoch 49/200
# 62/62 - 0s - loss: 0.0275 - val_loss: 0.0111 - 190ms/epoch - 3ms/step
# Epoch 50/200
# 62/62 - 0s - loss: 0.0297 - val_loss: 0.0114 - 153ms/epoch - 2ms/step
# Epoch 51/200
# 62/62 - 0s - loss: 0.0302 - val_loss: 0.0106 - 166ms/epoch - 3ms/step
# Epoch 52/200
# 62/62 - 0s - loss: 0.0281 - val_loss: 0.0124 - 156ms/epoch - 3ms/step
# Epoch 53/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0101 - 152ms/epoch - 2ms/step
# Epoch 54/200
# 62/62 - 0s - loss: 0.0277 - val_loss: 0.0102 - 157ms/epoch - 3ms/step
# Epoch 55/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0104 - 188ms/epoch - 3ms/step
# Epoch 56/200
# 62/62 - 0s - loss: 0.0273 - val_loss: 0.0111 - 179ms/epoch - 3ms/step
# Epoch 57/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0120 - 163ms/epoch - 3ms/step
# Epoch 58/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0105 - 149ms/epoch - 2ms/step
# Epoch 59/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0106 - 151ms/epoch - 2ms/step
# Epoch 60/200
# 62/62 - 0s - loss: 0.0275 - val_loss: 0.0103 - 158ms/epoch - 3ms/step
# Epoch 61/200
# 62/62 - 0s - loss: 0.0277 - val_loss: 0.0102 - 180ms/epoch - 3ms/step
# Epoch 62/200
# 62/62 - 0s - loss: 0.0269 - val_loss: 0.0117 - 150ms/epoch - 2ms/step
# Epoch 63/200
# 62/62 - 0s - loss: 0.0279 - val_loss: 0.0102 - 197ms/epoch - 3ms/step
# Epoch 64/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0114 - 155ms/epoch - 2ms/step
# Epoch 65/200
# 62/62 - 0s - loss: 0.0284 - val_loss: 0.0105 - 180ms/epoch - 3ms/step
# Epoch 66/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0120 - 178ms/epoch - 3ms/step
# Epoch 67/200
# 62/62 - 0s - loss: 0.0283 - val_loss: 0.0134 - 165ms/epoch - 3ms/step
# Epoch 68/200
# 62/62 - 0s - loss: 0.0279 - val_loss: 0.0110 - 177ms/epoch - 3ms/step
# Epoch 69/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0122 - 162ms/epoch - 3ms/step
# Epoch 70/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0127 - 155ms/epoch - 2ms/step
# Epoch 71/200
# 62/62 - 0s - loss: 0.0302 - val_loss: 0.0126 - 180ms/epoch - 3ms/step
# Epoch 72/200
# 62/62 - 0s - loss: 0.0279 - val_loss: 0.0102 - 153ms/epoch - 2ms/step
# Epoch 73/200
# 62/62 - 0s - loss: 0.0269 - val_loss: 0.0102 - 189ms/epoch - 3ms/step
# Epoch 74/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0113 - 179ms/epoch - 3ms/step
# Epoch 75/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0125 - 191ms/epoch - 3ms/step
# Epoch 76/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0103 - 149ms/epoch - 2ms/step
# Epoch 77/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0118 - 154ms/epoch - 2ms/step
# Epoch 78/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0101 - 182ms/epoch - 3ms/step
# Epoch 79/200
# 62/62 - 0s - loss: 0.0274 - val_loss: 0.0107 - 184ms/epoch - 3ms/step
# Epoch 80/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0122 - 179ms/epoch - 3ms/step
# Epoch 81/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0104 - 179ms/epoch - 3ms/step
# Epoch 82/200
# 62/62 - 0s - loss: 0.0280 - val_loss: 0.0100 - 233ms/epoch - 4ms/step
# Epoch 83/200
# 62/62 - 0s - loss: 0.0298 - val_loss: 0.0100 - 235ms/epoch - 4ms/step
# Epoch 84/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0127 - 242ms/epoch - 4ms/step
# Epoch 85/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0102 - 247ms/epoch - 4ms/step
# Epoch 86/200
# 62/62 - 0s - loss: 0.0281 - val_loss: 0.0100 - 203ms/epoch - 3ms/step
# Epoch 87/200
# 62/62 - 0s - loss: 0.0278 - val_loss: 0.0114 - 208ms/epoch - 3ms/step
# Epoch 88/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0105 - 225ms/epoch - 4ms/step
# Epoch 89/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0107 - 227ms/epoch - 4ms/step
# Epoch 90/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0106 - 244ms/epoch - 4ms/step
# Epoch 91/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0137 - 233ms/epoch - 4ms/step
# Epoch 92/200
# 62/62 - 0s - loss: 0.0284 - val_loss: 0.0167 - 237ms/epoch - 4ms/step
# Epoch 93/200
# 62/62 - 0s - loss: 0.0281 - val_loss: 0.0104 - 267ms/epoch - 4ms/step
# Epoch 94/200
# 62/62 - 0s - loss: 0.0284 - val_loss: 0.0101 - 246ms/epoch - 4ms/step
# Epoch 95/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0104 - 184ms/epoch - 3ms/step
# Epoch 96/200
# 62/62 - 0s - loss: 0.0269 - val_loss: 0.0109 - 153ms/epoch - 2ms/step
# Epoch 97/200
# 62/62 - 0s - loss: 0.0292 - val_loss: 0.0103 - 150ms/epoch - 2ms/step
# Epoch 98/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0112 - 174ms/epoch - 3ms/step
# Epoch 99/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0103 - 192ms/epoch - 3ms/step
# Epoch 100/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0105 - 151ms/epoch - 2ms/step
# Epoch 101/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0125 - 179ms/epoch - 3ms/step
# Epoch 102/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0102 - 180ms/epoch - 3ms/step
# Epoch 103/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0110 - 153ms/epoch - 2ms/step
# Epoch 104/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0113 - 199ms/epoch - 3ms/step
# Epoch 105/200
# 62/62 - 0s - loss: 0.0284 - val_loss: 0.0105 - 158ms/epoch - 3ms/step
# Epoch 106/200
# 62/62 - 0s - loss: 0.0279 - val_loss: 0.0103 - 155ms/epoch - 2ms/step
# Epoch 107/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0104 - 176ms/epoch - 3ms/step
# Epoch 108/200
# 62/62 - 0s - loss: 0.0279 - val_loss: 0.0104 - 152ms/epoch - 2ms/step
# Epoch 109/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0117 - 153ms/epoch - 2ms/step
# Epoch 110/200
# 62/62 - 0s - loss: 0.0277 - val_loss: 0.0139 - 174ms/epoch - 3ms/step
# Epoch 111/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0135 - 155ms/epoch - 3ms/step
# Epoch 112/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0105 - 159ms/epoch - 3ms/step
# Epoch 113/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0103 - 157ms/epoch - 3ms/step
# Epoch 114/200
# 62/62 - 0s - loss: 0.0269 - val_loss: 0.0118 - 152ms/epoch - 2ms/step
# Epoch 115/200
# 62/62 - 0s - loss: 0.0287 - val_loss: 0.0131 - 150ms/epoch - 2ms/step
# Epoch 116/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0147 - 178ms/epoch - 3ms/step
# Epoch 117/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0109 - 159ms/epoch - 3ms/step
# Epoch 118/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0116 - 153ms/epoch - 2ms/step
# Epoch 119/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0115 - 150ms/epoch - 2ms/step
# Epoch 120/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0101 - 154ms/epoch - 2ms/step
# Epoch 121/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0102 - 156ms/epoch - 3ms/step
# Epoch 122/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0105 - 176ms/epoch - 3ms/step
# Epoch 123/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0112 - 174ms/epoch - 3ms/step
# Epoch 124/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0104 - 152ms/epoch - 2ms/step
# Epoch 125/200
# 62/62 - 0s - loss: 0.0269 - val_loss: 0.0103 - 153ms/epoch - 2ms/step
# Epoch 126/200
# 62/62 - 0s - loss: 0.0263 - val_loss: 0.0126 - 156ms/epoch - 3ms/step
# Epoch 127/200
# 62/62 - 0s - loss: 0.0275 - val_loss: 0.0139 - 153ms/epoch - 2ms/step
# Epoch 128/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0110 - 159ms/epoch - 3ms/step
# Epoch 129/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0106 - 176ms/epoch - 3ms/step
# Epoch 130/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0106 - 181ms/epoch - 3ms/step
# Epoch 131/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0107 - 154ms/epoch - 2ms/step
# Epoch 132/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0108 - 183ms/epoch - 3ms/step
# Epoch 133/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0103 - 154ms/epoch - 2ms/step
# Epoch 134/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0107 - 180ms/epoch - 3ms/step
# Epoch 135/200
# 62/62 - 0s - loss: 0.0275 - val_loss: 0.0101 - 167ms/epoch - 3ms/step
# Epoch 136/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0104 - 179ms/epoch - 3ms/step
# Epoch 137/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0124 - 153ms/epoch - 2ms/step
# Epoch 138/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0102 - 158ms/epoch - 3ms/step
# Epoch 139/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0104 - 156ms/epoch - 3ms/step
# Epoch 140/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0101 - 152ms/epoch - 2ms/step
# Epoch 141/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0104 - 195ms/epoch - 3ms/step
# Epoch 142/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0153 - 181ms/epoch - 3ms/step
# Epoch 143/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0105 - 180ms/epoch - 3ms/step
# Epoch 144/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0100 - 160ms/epoch - 3ms/step
# Epoch 145/200
# 62/62 - 0s - loss: 0.0270 - val_loss: 0.0101 - 180ms/epoch - 3ms/step
# Epoch 146/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0120 - 190ms/epoch - 3ms/step
# Epoch 147/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0102 - 191ms/epoch - 3ms/step
# Epoch 148/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0117 - 149ms/epoch - 2ms/step
# Epoch 149/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0104 - 176ms/epoch - 3ms/step
# Epoch 150/200
# 62/62 - 0s - loss: 0.0274 - val_loss: 0.0128 - 154ms/epoch - 2ms/step
# Epoch 151/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0121 - 152ms/epoch - 2ms/step
# Epoch 152/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0103 - 188ms/epoch - 3ms/step
# Epoch 153/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0106 - 163ms/epoch - 3ms/step
# Epoch 154/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0114 - 229ms/epoch - 4ms/step
# Epoch 155/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0102 - 236ms/epoch - 4ms/step
# Epoch 156/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0125 - 248ms/epoch - 4ms/step
# Epoch 157/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0105 - 238ms/epoch - 4ms/step
# Epoch 158/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0114 - 215ms/epoch - 3ms/step
# Epoch 159/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0120 - 218ms/epoch - 4ms/step
# Epoch 160/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0105 - 235ms/epoch - 4ms/step
# Epoch 161/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0113 - 257ms/epoch - 4ms/step
# Epoch 162/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0105 - 233ms/epoch - 4ms/step
# Epoch 163/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0103 - 237ms/epoch - 4ms/step
# Epoch 164/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0124 - 236ms/epoch - 4ms/step
# Epoch 165/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0141 - 261ms/epoch - 4ms/step
# Epoch 166/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0117 - 264ms/epoch - 4ms/step
# Epoch 167/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0110 - 155ms/epoch - 3ms/step
# Epoch 168/200
# 62/62 - 0s - loss: 0.0254 - val_loss: 0.0118 - 179ms/epoch - 3ms/step
# Epoch 169/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0113 - 154ms/epoch - 2ms/step
# Epoch 170/200
# 62/62 - 0s - loss: 0.0250 - val_loss: 0.0103 - 189ms/epoch - 3ms/step
# Epoch 171/200
# 62/62 - 0s - loss: 0.0273 - val_loss: 0.0104 - 159ms/epoch - 3ms/step
# Epoch 172/200
# 62/62 - 0s - loss: 0.0264 - val_loss: 0.0103 - 188ms/epoch - 3ms/step
# Epoch 173/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0101 - 157ms/epoch - 3ms/step
# Epoch 174/200
# 62/62 - 0s - loss: 0.0246 - val_loss: 0.0138 - 178ms/epoch - 3ms/step
# Epoch 175/200
# 62/62 - 0s - loss: 0.0275 - val_loss: 0.0101 - 183ms/epoch - 3ms/step
# Epoch 176/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0124 - 154ms/epoch - 2ms/step
# Epoch 177/200
# 62/62 - 0s - loss: 0.0277 - val_loss: 0.0116 - 178ms/epoch - 3ms/step
# Epoch 178/200
# 62/62 - 0s - loss: 0.0265 - val_loss: 0.0108 - 201ms/epoch - 3ms/step
# Epoch 179/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0117 - 153ms/epoch - 2ms/step
# Epoch 180/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0105 - 159ms/epoch - 3ms/step
# Epoch 181/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0108 - 204ms/epoch - 3ms/step
# Epoch 182/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0103 - 152ms/epoch - 2ms/step
# Epoch 183/200
# 62/62 - 0s - loss: 0.0271 - val_loss: 0.0117 - 178ms/epoch - 3ms/step
# Epoch 184/200
# 62/62 - 0s - loss: 0.0259 - val_loss: 0.0101 - 175ms/epoch - 3ms/step
# Epoch 185/200
# 62/62 - 0s - loss: 0.0253 - val_loss: 0.0125 - 153ms/epoch - 2ms/step
# Epoch 186/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0109 - 179ms/epoch - 3ms/step
# Epoch 187/200
# 62/62 - 0s - loss: 0.0267 - val_loss: 0.0126 - 165ms/epoch - 3ms/step
# Epoch 188/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0134 - 182ms/epoch - 3ms/step
# Epoch 189/200
# 62/62 - 0s - loss: 0.0276 - val_loss: 0.0110 - 179ms/epoch - 3ms/step
# Epoch 190/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0123 - 157ms/epoch - 3ms/step
# Epoch 191/200
# 62/62 - 0s - loss: 0.0266 - val_loss: 0.0112 - 180ms/epoch - 3ms/step
# Epoch 192/200
# 62/62 - 0s - loss: 0.0256 - val_loss: 0.0116 - 158ms/epoch - 3ms/step
# Epoch 193/200
# 62/62 - 0s - loss: 0.0261 - val_loss: 0.0103 - 191ms/epoch - 3ms/step
# Epoch 194/200
# 62/62 - 0s - loss: 0.0268 - val_loss: 0.0105 - 180ms/epoch - 3ms/step
# Epoch 195/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0121 - 166ms/epoch - 3ms/step
# Epoch 196/200
# 62/62 - 0s - loss: 0.0258 - val_loss: 0.0133 - 181ms/epoch - 3ms/step
# Epoch 197/200
# 62/62 - 0s - loss: 0.0272 - val_loss: 0.0128 - 180ms/epoch - 3ms/step
# Epoch 198/200
# 62/62 - 0s - loss: 0.0260 - val_loss: 0.0101 - 162ms/epoch - 3ms/step
# Epoch 199/200
# 62/62 - 0s - loss: 0.0262 - val_loss: 0.0109 - 180ms/epoch - 3ms/step
# Epoch 200/200
# 62/62 - 0s - loss: 0.0257 - val_loss: 0.0106 - 184ms/epoch - 3ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step

# %% [markdown]
# شبکه LSTM

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# بستن تمام پنجره‌های نمودار باز
plt.close('all')

# بارگذاری داده‌ها از فایل CSV
df = pd.read_csv('example1.csv')

# دریافت لیست نام ستون‌ها
df_columns = list(df.columns)

# انتخاب ستون مورد نظر برای نمایش داده‌ها
selected_column = df_columns[5]

# انتخاب 100 داده اول از ستون مورد نظر
data_to_plot = df[selected_column][:99].values.reshape(-1,1)  # تبدیل به آرایه دو بعدی برای مقیاس‌بندی

# مقیاس‌بندی داده‌ها
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_to_plot)

# تقسیم داده‌ها به دو بخش آموزشی و تست
train_size = int(len(scaled_data) * 0.67)
test_size = len(scaled_data) - train_size
train, test = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# تابع برای ایجاد داده‌های آموزشی
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# ایجاد داده‌های آموزشی و تست
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# تغییر شکل ورودی‌ها برای LSTM
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# ایجاد و آموزش شبکه LSTM
model = Sequential()
model.add(LSTM(100, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2, validation_data=(testX, testY))

# پیش‌بینی‌ها
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# تبدیل پیش‌بینی‌ها به مقیاس اصلی
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# تعداد نقاط داده‌ای که می‌خواهیم پیش‌بینی کنیم
num_future_points = 20

# آخرین نقطه داده‌ای از مجموعه داده‌های آموزشی
last_point = trainX[-1]

# لیست برای نگهداری پیش‌بینی‌های آینده
future_predictions = []

# حلقه برای پیش‌بینی نقاط داده‌های آینده
for _ in range(num_future_points):
    # پیش‌بینی با استفاده از آخرین نقطه داده‌ای
    prediction = model.predict(last_point.reshape(1, 1, look_back))

    # اضافه کردن پیش‌بینی به لیست
    future_predictions.append(prediction[0,0])

    # به‌روزرسانی آخرین نقطه داده‌ای با استفاده از پیش‌بینی جدید
    last_point = np.roll(last_point, -1)
    last_point[-1] = prediction

# تبدیل پیش‌بینی‌های آینده به مقیاس اصلی
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# نمایش نمودارها
plt.figure(figsize=(10, 5))
plt.plot(trainY[0], label='Actual')
plt.plot(trainPredict[:,0], label='Predicted')
plt.title('Mohammad Mohammadi show the answer \n Train Data vs Predicted Data \n NOx ')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(testY[0], label='Actual')
plt.plot(testPredict[:,0], label='Predicted')
plt.title('Test Data vs Predicted Data \n NOx')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()



# اضافه کردن پیش‌بینی‌های آینده به نمودار
plt.figure(figsize=(10, 5))
plt.plot(range(len(trainY[0])), trainY[0], label='Actual')
plt.plot(range(len(trainPredict[:,0])), trainPredict[:,0], label='Predicted')
plt.plot(range(len(trainY[0]), len(trainY[0])+num_future_points), future_predictions[:,0], label='Future Predicted')
plt.title('Train Data vs Predicted Data vs Future Predicted Data \n NOx')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# رسم مقادیر خطای آموزش و تست
plt.subplot(2,1,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/200
# 62/62 - 2s - loss: 0.0052 - val_loss: 0.1110 - 2s/epoch - 40ms/step
# Epoch 2/200
# 62/62 - 0s - loss: 0.0028 - val_loss: 0.0872 - 256ms/epoch - 4ms/step
# Epoch 3/200
# 62/62 - 0s - loss: 0.0025 - val_loss: 0.0646 - 415ms/epoch - 7ms/step
# Epoch 4/200
# 62/62 - 0s - loss: 0.0021 - val_loss: 0.0448 - 324ms/epoch - 5ms/step
# Epoch 5/200
# 62/62 - 0s - loss: 0.0019 - val_loss: 0.0491 - 351ms/epoch - 6ms/step
# Epoch 6/200
# 62/62 - 0s - loss: 0.0018 - val_loss: 0.0355 - 449ms/epoch - 7ms/step
# Epoch 7/200
# 62/62 - 0s - loss: 0.0016 - val_loss: 0.0257 - 400ms/epoch - 6ms/step
# Epoch 8/200
# 62/62 - 0s - loss: 0.0015 - val_loss: 0.0278 - 350ms/epoch - 6ms/step
# Epoch 9/200
# 62/62 - 0s - loss: 0.0015 - val_loss: 0.0288 - 430ms/epoch - 7ms/step
# Epoch 10/200
# 62/62 - 0s - loss: 0.0016 - val_loss: 0.0194 - 435ms/epoch - 7ms/step
# Epoch 11/200
# 62/62 - 0s - loss: 0.0014 - val_loss: 0.0203 - 240ms/epoch - 4ms/step
# Epoch 12/200
# 62/62 - 0s - loss: 0.0013 - val_loss: 0.0208 - 222ms/epoch - 4ms/step
# Epoch 13/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0186 - 243ms/epoch - 4ms/step
# Epoch 14/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0221 - 234ms/epoch - 4ms/step
# Epoch 15/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0215 - 224ms/epoch - 4ms/step
# Epoch 16/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0178 - 231ms/epoch - 4ms/step
# Epoch 17/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0152 - 240ms/epoch - 4ms/step
# Epoch 18/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0173 - 245ms/epoch - 4ms/step
# Epoch 19/200
# 62/62 - 0s - loss: 9.8152e-04 - val_loss: 0.0174 - 236ms/epoch - 4ms/step
# Epoch 20/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0140 - 224ms/epoch - 4ms/step
# Epoch 21/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0165 - 231ms/epoch - 4ms/step
# Epoch 22/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0125 - 225ms/epoch - 4ms/step
# Epoch 23/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0131 - 224ms/epoch - 4ms/step
# Epoch 24/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0135 - 219ms/epoch - 4ms/step
# Epoch 25/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0132 - 242ms/epoch - 4ms/step
# Epoch 26/200
# 62/62 - 0s - loss: 9.8114e-04 - val_loss: 0.0144 - 246ms/epoch - 4ms/step
# Epoch 27/200
# 62/62 - 0s - loss: 9.4242e-04 - val_loss: 0.0102 - 240ms/epoch - 4ms/step
# Epoch 28/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0099 - 220ms/epoch - 4ms/step
# Epoch 29/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0143 - 264ms/epoch - 4ms/step
# Epoch 30/200
# 62/62 - 0s - loss: 9.3269e-04 - val_loss: 0.0127 - 233ms/epoch - 4ms/step
# Epoch 31/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0136 - 242ms/epoch - 4ms/step
# Epoch 32/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0125 - 226ms/epoch - 4ms/step
# Epoch 33/200
# 62/62 - 0s - loss: 9.6250e-04 - val_loss: 0.0179 - 265ms/epoch - 4ms/step
# Epoch 34/200
# 62/62 - 0s - loss: 8.9174e-04 - val_loss: 0.0108 - 246ms/epoch - 4ms/step
# Epoch 35/200
# 62/62 - 0s - loss: 9.6430e-04 - val_loss: 0.0115 - 239ms/epoch - 4ms/step
# Epoch 36/200
# 62/62 - 0s - loss: 9.1488e-04 - val_loss: 0.0085 - 232ms/epoch - 4ms/step
# Epoch 37/200
# 62/62 - 0s - loss: 9.4546e-04 - val_loss: 0.0129 - 234ms/epoch - 4ms/step
# Epoch 38/200
# 62/62 - 0s - loss: 9.7907e-04 - val_loss: 0.0126 - 235ms/epoch - 4ms/step
# Epoch 39/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0127 - 215ms/epoch - 3ms/step
# Epoch 40/200
# 62/62 - 0s - loss: 9.7693e-04 - val_loss: 0.0107 - 220ms/epoch - 4ms/step
# Epoch 41/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0117 - 223ms/epoch - 4ms/step
# Epoch 42/200
# 62/62 - 0s - loss: 9.0497e-04 - val_loss: 0.0144 - 235ms/epoch - 4ms/step
# Epoch 43/200
# 62/62 - 0s - loss: 8.7235e-04 - val_loss: 0.0155 - 228ms/epoch - 4ms/step
# Epoch 44/200
# 62/62 - 0s - loss: 9.5385e-04 - val_loss: 0.0157 - 230ms/epoch - 4ms/step
# Epoch 45/200
# 62/62 - 0s - loss: 8.8638e-04 - val_loss: 0.0113 - 205ms/epoch - 3ms/step
# Epoch 46/200
# 62/62 - 0s - loss: 9.5613e-04 - val_loss: 0.0115 - 232ms/epoch - 4ms/step
# Epoch 47/200
# 62/62 - 0s - loss: 9.0344e-04 - val_loss: 0.0130 - 234ms/epoch - 4ms/step
# Epoch 48/200
# 62/62 - 0s - loss: 9.1942e-04 - val_loss: 0.0134 - 216ms/epoch - 3ms/step
# Epoch 49/200
# 62/62 - 0s - loss: 9.0189e-04 - val_loss: 0.0134 - 237ms/epoch - 4ms/step
# Epoch 50/200
# 62/62 - 0s - loss: 8.7363e-04 - val_loss: 0.0109 - 216ms/epoch - 3ms/step
# Epoch 51/200
# 62/62 - 0s - loss: 9.9216e-04 - val_loss: 0.0109 - 218ms/epoch - 4ms/step
# Epoch 52/200
# 62/62 - 0s - loss: 9.3192e-04 - val_loss: 0.0140 - 233ms/epoch - 4ms/step
# Epoch 53/200
# 62/62 - 0s - loss: 8.8340e-04 - val_loss: 0.0154 - 398ms/epoch - 6ms/step
# Epoch 54/200
# 62/62 - 0s - loss: 9.4194e-04 - val_loss: 0.0138 - 414ms/epoch - 7ms/step
# Epoch 55/200
# 62/62 - 0s - loss: 8.9617e-04 - val_loss: 0.0148 - 369ms/epoch - 6ms/step
# Epoch 56/200
# 62/62 - 0s - loss: 9.5454e-04 - val_loss: 0.0127 - 334ms/epoch - 5ms/step
# Epoch 57/200
# 62/62 - 0s - loss: 9.3694e-04 - val_loss: 0.0130 - 434ms/epoch - 7ms/step
# Epoch 58/200
# 62/62 - 0s - loss: 9.3017e-04 - val_loss: 0.0163 - 416ms/epoch - 7ms/step
# Epoch 59/200
# 62/62 - 0s - loss: 9.0437e-04 - val_loss: 0.0154 - 442ms/epoch - 7ms/step
# Epoch 60/200
# 62/62 - 0s - loss: 8.8921e-04 - val_loss: 0.0155 - 347ms/epoch - 6ms/step
# Epoch 61/200
# 62/62 - 0s - loss: 8.6731e-04 - val_loss: 0.0179 - 244ms/epoch - 4ms/step
# Epoch 62/200
# 62/62 - 0s - loss: 8.9558e-04 - val_loss: 0.0108 - 243ms/epoch - 4ms/step
# Epoch 63/200
# 62/62 - 0s - loss: 8.6578e-04 - val_loss: 0.0158 - 260ms/epoch - 4ms/step
# Epoch 64/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0143 - 225ms/epoch - 4ms/step
# Epoch 65/200
# 62/62 - 0s - loss: 9.2936e-04 - val_loss: 0.0156 - 229ms/epoch - 4ms/step
# Epoch 66/200
# 62/62 - 0s - loss: 8.7656e-04 - val_loss: 0.0132 - 226ms/epoch - 4ms/step
# Epoch 67/200
# 62/62 - 0s - loss: 8.9187e-04 - val_loss: 0.0158 - 255ms/epoch - 4ms/step
# Epoch 68/200
# 62/62 - 0s - loss: 9.2634e-04 - val_loss: 0.0117 - 224ms/epoch - 4ms/step
# Epoch 69/200
# 62/62 - 0s - loss: 8.6434e-04 - val_loss: 0.0172 - 218ms/epoch - 4ms/step
# Epoch 70/200
# 62/62 - 0s - loss: 8.9519e-04 - val_loss: 0.0132 - 219ms/epoch - 4ms/step
# Epoch 71/200
# 62/62 - 0s - loss: 8.9954e-04 - val_loss: 0.0174 - 227ms/epoch - 4ms/step
# Epoch 72/200
# 62/62 - 0s - loss: 9.7032e-04 - val_loss: 0.0124 - 252ms/epoch - 4ms/step
# Epoch 73/200
# 62/62 - 0s - loss: 8.8669e-04 - val_loss: 0.0205 - 236ms/epoch - 4ms/step
# Epoch 74/200
# 62/62 - 0s - loss: 9.5067e-04 - val_loss: 0.0168 - 213ms/epoch - 3ms/step
# Epoch 75/200
# 62/62 - 0s - loss: 9.2237e-04 - val_loss: 0.0155 - 230ms/epoch - 4ms/step
# Epoch 76/200
# 62/62 - 0s - loss: 9.8093e-04 - val_loss: 0.0213 - 253ms/epoch - 4ms/step
# Epoch 77/200
# 62/62 - 0s - loss: 8.3989e-04 - val_loss: 0.0134 - 233ms/epoch - 4ms/step
# Epoch 78/200
# 62/62 - 0s - loss: 8.6567e-04 - val_loss: 0.0210 - 233ms/epoch - 4ms/step
# Epoch 79/200
# 62/62 - 0s - loss: 8.9453e-04 - val_loss: 0.0215 - 216ms/epoch - 3ms/step
# Epoch 80/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0142 - 241ms/epoch - 4ms/step
# Epoch 81/200
# 62/62 - 0s - loss: 8.6248e-04 - val_loss: 0.0164 - 238ms/epoch - 4ms/step
# Epoch 82/200
# 62/62 - 0s - loss: 8.7854e-04 - val_loss: 0.0128 - 235ms/epoch - 4ms/step
# Epoch 83/200
# 62/62 - 0s - loss: 9.0804e-04 - val_loss: 0.0177 - 223ms/epoch - 4ms/step
# Epoch 84/200
# 62/62 - 0s - loss: 9.1676e-04 - val_loss: 0.0145 - 262ms/epoch - 4ms/step
# Epoch 85/200
# 62/62 - 0s - loss: 8.8231e-04 - val_loss: 0.0230 - 256ms/epoch - 4ms/step
# Epoch 86/200
# 62/62 - 0s - loss: 8.5159e-04 - val_loss: 0.0189 - 239ms/epoch - 4ms/step
# Epoch 87/200
# 62/62 - 0s - loss: 8.5607e-04 - val_loss: 0.0216 - 249ms/epoch - 4ms/step
# Epoch 88/200
# 62/62 - 0s - loss: 9.1958e-04 - val_loss: 0.0152 - 246ms/epoch - 4ms/step
# Epoch 89/200
# 62/62 - 0s - loss: 9.0565e-04 - val_loss: 0.0221 - 257ms/epoch - 4ms/step
# Epoch 90/200
# 62/62 - 0s - loss: 8.7325e-04 - val_loss: 0.0164 - 241ms/epoch - 4ms/step
# Epoch 91/200
# 62/62 - 0s - loss: 8.5982e-04 - val_loss: 0.0190 - 271ms/epoch - 4ms/step
# Epoch 92/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0228 - 263ms/epoch - 4ms/step
# Epoch 93/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0171 - 251ms/epoch - 4ms/step
# Epoch 94/200
# 62/62 - 0s - loss: 8.6130e-04 - val_loss: 0.0131 - 253ms/epoch - 4ms/step
# Epoch 95/200
# 62/62 - 0s - loss: 9.3670e-04 - val_loss: 0.0149 - 235ms/epoch - 4ms/step
# Epoch 96/200
# 62/62 - 0s - loss: 8.7254e-04 - val_loss: 0.0137 - 237ms/epoch - 4ms/step
# Epoch 97/200
# 62/62 - 0s - loss: 9.0277e-04 - val_loss: 0.0178 - 230ms/epoch - 4ms/step
# Epoch 98/200
# 62/62 - 0s - loss: 8.6981e-04 - val_loss: 0.0217 - 216ms/epoch - 3ms/step
# Epoch 99/200
# 62/62 - 0s - loss: 8.9221e-04 - val_loss: 0.0190 - 204ms/epoch - 3ms/step
# Epoch 100/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0221 - 225ms/epoch - 4ms/step
# Epoch 101/200
# 62/62 - 0s - loss: 9.2899e-04 - val_loss: 0.0247 - 248ms/epoch - 4ms/step
# Epoch 102/200
# 62/62 - 0s - loss: 8.5864e-04 - val_loss: 0.0165 - 316ms/epoch - 5ms/step
# Epoch 103/200
# 62/62 - 0s - loss: 9.3484e-04 - val_loss: 0.0214 - 336ms/epoch - 5ms/step
# Epoch 104/200
# 62/62 - 0s - loss: 8.0497e-04 - val_loss: 0.0144 - 386ms/epoch - 6ms/step
# Epoch 105/200
# 62/62 - 0s - loss: 8.7571e-04 - val_loss: 0.0167 - 409ms/epoch - 7ms/step
# Epoch 106/200
# 62/62 - 0s - loss: 8.3737e-04 - val_loss: 0.0220 - 335ms/epoch - 5ms/step
# Epoch 107/200
# 62/62 - 0s - loss: 8.4438e-04 - val_loss: 0.0181 - 417ms/epoch - 7ms/step
# Epoch 108/200
# 62/62 - 0s - loss: 9.4834e-04 - val_loss: 0.0237 - 319ms/epoch - 5ms/step
# Epoch 109/200
# 62/62 - 0s - loss: 8.8563e-04 - val_loss: 0.0178 - 375ms/epoch - 6ms/step
# Epoch 110/200
# 62/62 - 0s - loss: 8.6645e-04 - val_loss: 0.0170 - 347ms/epoch - 6ms/step
# Epoch 111/200
# 62/62 - 0s - loss: 9.3336e-04 - val_loss: 0.0167 - 242ms/epoch - 4ms/step
# Epoch 112/200
# 62/62 - 0s - loss: 8.9436e-04 - val_loss: 0.0214 - 231ms/epoch - 4ms/step
# Epoch 113/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0194 - 211ms/epoch - 3ms/step
# Epoch 114/200
# 62/62 - 0s - loss: 8.7764e-04 - val_loss: 0.0177 - 245ms/epoch - 4ms/step
# Epoch 115/200
# 62/62 - 0s - loss: 8.1366e-04 - val_loss: 0.0158 - 235ms/epoch - 4ms/step
# Epoch 116/200
# 62/62 - 0s - loss: 9.0626e-04 - val_loss: 0.0206 - 243ms/epoch - 4ms/step
# Epoch 117/200
# 62/62 - 0s - loss: 9.0695e-04 - val_loss: 0.0214 - 256ms/epoch - 4ms/step
# Epoch 118/200
# 62/62 - 0s - loss: 9.1153e-04 - val_loss: 0.0203 - 248ms/epoch - 4ms/step
# Epoch 119/200
# 62/62 - 0s - loss: 8.6034e-04 - val_loss: 0.0200 - 254ms/epoch - 4ms/step
# Epoch 120/200
# 62/62 - 0s - loss: 7.9776e-04 - val_loss: 0.0243 - 249ms/epoch - 4ms/step
# Epoch 121/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0209 - 245ms/epoch - 4ms/step
# Epoch 122/200
# 62/62 - 0s - loss: 9.3798e-04 - val_loss: 0.0209 - 237ms/epoch - 4ms/step
# Epoch 123/200
# 62/62 - 0s - loss: 8.7767e-04 - val_loss: 0.0233 - 223ms/epoch - 4ms/step
# Epoch 124/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0186 - 233ms/epoch - 4ms/step
# Epoch 125/200
# 62/62 - 0s - loss: 8.4443e-04 - val_loss: 0.0221 - 250ms/epoch - 4ms/step
# Epoch 126/200
# 62/62 - 0s - loss: 8.1388e-04 - val_loss: 0.0201 - 252ms/epoch - 4ms/step
# Epoch 127/200
# 62/62 - 0s - loss: 8.9922e-04 - val_loss: 0.0204 - 235ms/epoch - 4ms/step
# Epoch 128/200
# 62/62 - 0s - loss: 8.4674e-04 - val_loss: 0.0174 - 228ms/epoch - 4ms/step
# Epoch 129/200
# 62/62 - 0s - loss: 8.6056e-04 - val_loss: 0.0181 - 222ms/epoch - 4ms/step
# Epoch 130/200
# 62/62 - 0s - loss: 8.8062e-04 - val_loss: 0.0210 - 210ms/epoch - 3ms/step
# Epoch 131/200
# 62/62 - 0s - loss: 9.0332e-04 - val_loss: 0.0219 - 246ms/epoch - 4ms/step
# Epoch 132/200
# 62/62 - 0s - loss: 8.7585e-04 - val_loss: 0.0199 - 225ms/epoch - 4ms/step
# Epoch 133/200
# 62/62 - 0s - loss: 8.6191e-04 - val_loss: 0.0238 - 258ms/epoch - 4ms/step
# Epoch 134/200
# 62/62 - 0s - loss: 9.0970e-04 - val_loss: 0.0176 - 224ms/epoch - 4ms/step
# Epoch 135/200
# 62/62 - 0s - loss: 8.6131e-04 - val_loss: 0.0193 - 251ms/epoch - 4ms/step
# Epoch 136/200
# 62/62 - 0s - loss: 9.8006e-04 - val_loss: 0.0184 - 264ms/epoch - 4ms/step
# Epoch 137/200
# 62/62 - 0s - loss: 8.6175e-04 - val_loss: 0.0225 - 267ms/epoch - 4ms/step
# Epoch 138/200
# 62/62 - 0s - loss: 8.4468e-04 - val_loss: 0.0230 - 230ms/epoch - 4ms/step
# Epoch 139/200
# 62/62 - 0s - loss: 9.0259e-04 - val_loss: 0.0219 - 242ms/epoch - 4ms/step
# Epoch 140/200
# 62/62 - 0s - loss: 8.2490e-04 - val_loss: 0.0220 - 218ms/epoch - 4ms/step
# Epoch 141/200
# 62/62 - 0s - loss: 8.3002e-04 - val_loss: 0.0247 - 225ms/epoch - 4ms/step
# Epoch 142/200
# 62/62 - 0s - loss: 8.8360e-04 - val_loss: 0.0260 - 247ms/epoch - 4ms/step
# Epoch 143/200
# 62/62 - 0s - loss: 9.0616e-04 - val_loss: 0.0215 - 208ms/epoch - 3ms/step
# Epoch 144/200
# 62/62 - 0s - loss: 8.2828e-04 - val_loss: 0.0247 - 250ms/epoch - 4ms/step
# Epoch 145/200
# 62/62 - 0s - loss: 8.3813e-04 - val_loss: 0.0246 - 228ms/epoch - 4ms/step
# Epoch 146/200
# 62/62 - 0s - loss: 7.9580e-04 - val_loss: 0.0284 - 223ms/epoch - 4ms/step
# Epoch 147/200
# 62/62 - 0s - loss: 8.3258e-04 - val_loss: 0.0255 - 233ms/epoch - 4ms/step
# Epoch 148/200
# 62/62 - 0s - loss: 8.3948e-04 - val_loss: 0.0189 - 253ms/epoch - 4ms/step
# Epoch 149/200
# 62/62 - 0s - loss: 9.4581e-04 - val_loss: 0.0201 - 260ms/epoch - 4ms/step
# Epoch 150/200
# 62/62 - 0s - loss: 8.3545e-04 - val_loss: 0.0264 - 245ms/epoch - 4ms/step
# Epoch 151/200
# 62/62 - 0s - loss: 8.9042e-04 - val_loss: 0.0267 - 233ms/epoch - 4ms/step
# Epoch 152/200
# 62/62 - 0s - loss: 7.8108e-04 - val_loss: 0.0315 - 385ms/epoch - 6ms/step
# Epoch 153/200
# 62/62 - 0s - loss: 9.0982e-04 - val_loss: 0.0301 - 362ms/epoch - 6ms/step
# Epoch 154/200
# 62/62 - 0s - loss: 8.5265e-04 - val_loss: 0.0251 - 321ms/epoch - 5ms/step
# Epoch 155/200
# 62/62 - 0s - loss: 8.5226e-04 - val_loss: 0.0260 - 348ms/epoch - 6ms/step
# Epoch 156/200
# 62/62 - 0s - loss: 8.2410e-04 - val_loss: 0.0250 - 426ms/epoch - 7ms/step
# Epoch 157/200
# 62/62 - 0s - loss: 8.2304e-04 - val_loss: 0.0320 - 347ms/epoch - 6ms/step
# Epoch 158/200
# 62/62 - 0s - loss: 8.5121e-04 - val_loss: 0.0306 - 448ms/epoch - 7ms/step
# Epoch 159/200
# 62/62 - 0s - loss: 8.1119e-04 - val_loss: 0.0300 - 343ms/epoch - 6ms/step
# Epoch 160/200
# 62/62 - 0s - loss: 7.8655e-04 - val_loss: 0.0318 - 215ms/epoch - 3ms/step
# Epoch 161/200
# 62/62 - 0s - loss: 7.8725e-04 - val_loss: 0.0253 - 238ms/epoch - 4ms/step
# Epoch 162/200
# 62/62 - 0s - loss: 9.0132e-04 - val_loss: 0.0188 - 244ms/epoch - 4ms/step
# Epoch 163/200
# 62/62 - 0s - loss: 8.5655e-04 - val_loss: 0.0295 - 224ms/epoch - 4ms/step
# Epoch 164/200
# 62/62 - 0s - loss: 8.1765e-04 - val_loss: 0.0302 - 238ms/epoch - 4ms/step
# Epoch 165/200
# 62/62 - 0s - loss: 8.7994e-04 - val_loss: 0.0271 - 246ms/epoch - 4ms/step
# Epoch 166/200
# 62/62 - 0s - loss: 8.7526e-04 - val_loss: 0.0320 - 252ms/epoch - 4ms/step
# Epoch 167/200
# 62/62 - 0s - loss: 7.9681e-04 - val_loss: 0.0249 - 250ms/epoch - 4ms/step
# Epoch 168/200
# 62/62 - 0s - loss: 8.1863e-04 - val_loss: 0.0236 - 218ms/epoch - 4ms/step
# Epoch 169/200
# 62/62 - 0s - loss: 8.7371e-04 - val_loss: 0.0295 - 220ms/epoch - 4ms/step
# Epoch 170/200
# 62/62 - 0s - loss: 8.5174e-04 - val_loss: 0.0249 - 247ms/epoch - 4ms/step
# Epoch 171/200
# 62/62 - 0s - loss: 8.4525e-04 - val_loss: 0.0305 - 230ms/epoch - 4ms/step
# Epoch 172/200
# 62/62 - 0s - loss: 8.2893e-04 - val_loss: 0.0286 - 247ms/epoch - 4ms/step
# Epoch 173/200
# 62/62 - 0s - loss: 9.5369e-04 - val_loss: 0.0305 - 229ms/epoch - 4ms/step
# Epoch 174/200
# 62/62 - 0s - loss: 8.7434e-04 - val_loss: 0.0288 - 271ms/epoch - 4ms/step
# Epoch 175/200
# 62/62 - 0s - loss: 9.2453e-04 - val_loss: 0.0360 - 260ms/epoch - 4ms/step
# Epoch 176/200
# 62/62 - 0s - loss: 8.4532e-04 - val_loss: 0.0306 - 250ms/epoch - 4ms/step
# Epoch 177/200
# 62/62 - 0s - loss: 8.1436e-04 - val_loss: 0.0288 - 226ms/epoch - 4ms/step
# Epoch 178/200
# 62/62 - 0s - loss: 8.3901e-04 - val_loss: 0.0317 - 262ms/epoch - 4ms/step
# Epoch 179/200
# 62/62 - 0s - loss: 8.2164e-04 - val_loss: 0.0329 - 257ms/epoch - 4ms/step
# Epoch 180/200
# 62/62 - 0s - loss: 8.7906e-04 - val_loss: 0.0291 - 229ms/epoch - 4ms/step
# Epoch 181/200
# 62/62 - 0s - loss: 8.0919e-04 - val_loss: 0.0313 - 226ms/epoch - 4ms/step
# Epoch 182/200
# 62/62 - 0s - loss: 8.1876e-04 - val_loss: 0.0351 - 248ms/epoch - 4ms/step
# Epoch 183/200
# 62/62 - 0s - loss: 8.8178e-04 - val_loss: 0.0365 - 234ms/epoch - 4ms/step
# Epoch 184/200
# 62/62 - 0s - loss: 8.2505e-04 - val_loss: 0.0388 - 243ms/epoch - 4ms/step
# Epoch 185/200
# 62/62 - 0s - loss: 9.3310e-04 - val_loss: 0.0287 - 224ms/epoch - 4ms/step
# Epoch 186/200
# 62/62 - 0s - loss: 8.4426e-04 - val_loss: 0.0294 - 251ms/epoch - 4ms/step
# Epoch 187/200
# 62/62 - 0s - loss: 7.6785e-04 - val_loss: 0.0253 - 237ms/epoch - 4ms/step
# Epoch 188/200
# 62/62 - 0s - loss: 9.4896e-04 - val_loss: 0.0290 - 245ms/epoch - 4ms/step
# Epoch 189/200
# 62/62 - 0s - loss: 8.8067e-04 - val_loss: 0.0310 - 250ms/epoch - 4ms/step
# Epoch 190/200
# 62/62 - 0s - loss: 7.9590e-04 - val_loss: 0.0350 - 239ms/epoch - 4ms/step
# Epoch 191/200
# 62/62 - 0s - loss: 8.8191e-04 - val_loss: 0.0398 - 232ms/epoch - 4ms/step
# Epoch 192/200
# 62/62 - 0s - loss: 8.1946e-04 - val_loss: 0.0405 - 257ms/epoch - 4ms/step
# Epoch 193/200
# 62/62 - 0s - loss: 8.0479e-04 - val_loss: 0.0375 - 234ms/epoch - 4ms/step
# Epoch 194/200
# 62/62 - 0s - loss: 8.3338e-04 - val_loss: 0.0398 - 251ms/epoch - 4ms/step
# Epoch 195/200
# 62/62 - 0s - loss: 9.1489e-04 - val_loss: 0.0392 - 248ms/epoch - 4ms/step
# Epoch 196/200
# 62/62 - 0s - loss: 8.2672e-04 - val_loss: 0.0415 - 244ms/epoch - 4ms/step
# Epoch 197/200
# 62/62 - 0s - loss: 9.5337e-04 - val_loss: 0.0378 - 237ms/epoch - 4ms/step
# Epoch 198/200
# 62/62 - 0s - loss: 8.1574e-04 - val_loss: 0.0378 - 245ms/epoch - 4ms/step
# Epoch 199/200
# 62/62 - 0s - loss: 7.9783e-04 - val_loss: 0.0343 - 258ms/epoch - 4ms/step
# Epoch 200/200
# 62/62 - 0s - loss: 9.3168e-04 - val_loss: 0.0290 - 346ms/epoch - 6ms/step
# 2/2 [==============================] - 1s 9ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# شبکه RNN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

# بستن تمام پنجره‌های نمودار باز
plt.close('all')

# بارگذاری داده‌ها از فایل CSV
df = pd.read_csv('example1.csv')

# دریافت لیست نام ستون‌ها
df_columns = list(df.columns)

# انتخاب ستون مورد نظر برای نمایش داده‌ها
selected_column = df_columns[5]

# انتخاب 100 داده اول از ستون مورد نظر
data_to_plot = df[selected_column][:99].values.reshape(-1,1)  # تبدیل به آرایه دو بعدی برای مقیاس‌بندی

# مقیاس‌بندی داده‌ها
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data_to_plot)

# تقسیم داده‌ها به دو بخش آموزشی و تست
train_size = int(len(scaled_data) * 0.67)
test_size = len(scaled_data) - train_size
train, test = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# تابع برای ایجاد داده‌های آموزشی
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# ایجاد داده‌های آموزشی و تست
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# تغییر شکل ورودی‌ها برای RNN
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# ایجاد و آموزش شبکه RNN
model = Sequential()
model.add(SimpleRNN(100, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(trainX, trainY, epochs=200, batch_size=1, verbose=2, validation_data=(testX, testY))

# پیش‌بینی‌ها
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# تبدیل پیش‌بینی‌ها به مقیاس اصلی
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# تعداد نقاط داده‌ای که می‌خواهیم پیش‌بینی کنیم
num_future_points = 20

# آخرین نقطه داده‌ای از مجموعه داده‌های آموزشی
last_point = trainX[-1]

# لیست برای نگهداری پیش‌بینی‌های آینده
future_predictions = []

# حلقه برای پیش‌بینی نقاط داده‌های آینده
for _ in range(num_future_points):
    # پیش‌بینی با استفاده از آخرین نقطه داده‌ای
    prediction = model.predict(last_point.reshape(1, 1, look_back))

        # اضافه کردن پیش‌بینی به لیست
    future_predictions.append(prediction[0,0])

    # به‌روزرسانی آخرین نقطه داده‌ای با استفاده از پیش‌بینی جدید
    last_point = np.roll(last_point, -1)
    last_point[-1] = prediction

# تبدیل پیش‌بینی‌های آینده به مقیاس اصلی
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# نمایش نمودارها
plt.figure(figsize=(10, 5))
plt.plot(trainY[0], label='Actual')
plt.plot(trainPredict[:,0], label='Predicted')
plt.title('Train Data vs Predicted Data \n NOx')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(testY[0], label='Actual')
plt.plot(testPredict[:,0], label='Predicted')
plt.title('Test Data vs Predicted Data \n NOx')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# اضافه کردن پیش‌بینی‌های آینده به نمودار
plt.figure(figsize=(10, 5))
plt.plot(range(len(trainY[0])), trainY[0], label='Actual')
plt.plot(range(len(trainPredict[:,0])), trainPredict[:,0], label='Predicted')
plt.plot(range(len(trainY[0]), len(trainY[0])+num_future_points), future_predictions[:,0], label='Future Predicted')
plt.title('Train Data vs Predicted Data vs Future Predicted Data \n NOx')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# رسم مقادیر خطای آموزش و تست
plt.subplot(2,1,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# Epoch 1/200
# 62/62 - 2s - loss: 0.0028 - val_loss: 0.0516 - 2s/epoch - 33ms/step
# Epoch 2/200
# 62/62 - 0s - loss: 0.0018 - val_loss: 0.0239 - 255ms/epoch - 4ms/step
# Epoch 3/200
# 62/62 - 0s - loss: 0.0014 - val_loss: 0.0181 - 185ms/epoch - 3ms/step
# Epoch 4/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0180 - 164ms/epoch - 3ms/step
# Epoch 5/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0205 - 174ms/epoch - 3ms/step
# Epoch 6/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0154 - 168ms/epoch - 3ms/step
# Epoch 7/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0279 - 188ms/epoch - 3ms/step
# Epoch 8/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0164 - 208ms/epoch - 3ms/step
# Epoch 9/200
# 62/62 - 0s - loss: 9.4316e-04 - val_loss: 0.0102 - 163ms/epoch - 3ms/step
# Epoch 10/200
# 62/62 - 0s - loss: 8.9222e-04 - val_loss: 0.0093 - 189ms/epoch - 3ms/step
# Epoch 11/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0120 - 175ms/epoch - 3ms/step
# Epoch 12/200
# 62/62 - 0s - loss: 9.6254e-04 - val_loss: 0.0157 - 185ms/epoch - 3ms/step
# Epoch 13/200
# 62/62 - 0s - loss: 9.3228e-04 - val_loss: 0.0131 - 171ms/epoch - 3ms/step
# Epoch 14/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0350 - 180ms/epoch - 3ms/step
# Epoch 15/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0062 - 158ms/epoch - 3ms/step
# Epoch 16/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0072 - 155ms/epoch - 2ms/step
# Epoch 17/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0151 - 190ms/epoch - 3ms/step
# Epoch 18/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0106 - 181ms/epoch - 3ms/step
# Epoch 19/200
# 62/62 - 0s - loss: 9.2596e-04 - val_loss: 0.0060 - 168ms/epoch - 3ms/step
# Epoch 20/200
# 62/62 - 0s - loss: 0.0013 - val_loss: 0.0069 - 158ms/epoch - 3ms/step
# Epoch 21/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0084 - 182ms/epoch - 3ms/step
# Epoch 22/200
# 62/62 - 0s - loss: 0.0013 - val_loss: 0.0114 - 167ms/epoch - 3ms/step
# Epoch 23/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0127 - 186ms/epoch - 3ms/step
# Epoch 24/200
# 62/62 - 0s - loss: 9.2234e-04 - val_loss: 0.0193 - 182ms/epoch - 3ms/step
# Epoch 25/200
# 62/62 - 0s - loss: 9.8823e-04 - val_loss: 0.0140 - 187ms/epoch - 3ms/step
# Epoch 26/200
# 62/62 - 0s - loss: 9.8664e-04 - val_loss: 0.0140 - 152ms/epoch - 2ms/step
# Epoch 27/200
# 62/62 - 0s - loss: 8.9437e-04 - val_loss: 0.0108 - 156ms/epoch - 3ms/step
# Epoch 28/200
# 62/62 - 0s - loss: 9.4951e-04 - val_loss: 0.0125 - 194ms/epoch - 3ms/step
# Epoch 29/200
# 62/62 - 0s - loss: 8.9938e-04 - val_loss: 0.0146 - 181ms/epoch - 3ms/step
# Epoch 30/200
# 62/62 - 0s - loss: 9.8297e-04 - val_loss: 0.0119 - 174ms/epoch - 3ms/step
# Epoch 31/200
# 62/62 - 0s - loss: 9.8857e-04 - val_loss: 0.0120 - 163ms/epoch - 3ms/step
# Epoch 32/200
# 62/62 - 0s - loss: 9.6558e-04 - val_loss: 0.0116 - 152ms/epoch - 2ms/step
# Epoch 33/200
# 62/62 - 0s - loss: 8.3863e-04 - val_loss: 0.0117 - 181ms/epoch - 3ms/step
# Epoch 34/200
# 62/62 - 0s - loss: 9.1764e-04 - val_loss: 0.0169 - 163ms/epoch - 3ms/step
# Epoch 35/200
# 62/62 - 0s - loss: 9.7056e-04 - val_loss: 0.0091 - 186ms/epoch - 3ms/step
# Epoch 36/200
# 62/62 - 0s - loss: 8.8115e-04 - val_loss: 0.0177 - 193ms/epoch - 3ms/step
# Epoch 37/200
# 62/62 - 0s - loss: 9.6466e-04 - val_loss: 0.0118 - 188ms/epoch - 3ms/step
# Epoch 38/200
# 62/62 - 0s - loss: 9.6502e-04 - val_loss: 0.0157 - 155ms/epoch - 2ms/step
# Epoch 39/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0101 - 154ms/epoch - 2ms/step
# Epoch 40/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0103 - 200ms/epoch - 3ms/step
# Epoch 41/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0124 - 158ms/epoch - 3ms/step
# Epoch 42/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0154 - 166ms/epoch - 3ms/step
# Epoch 43/200
# 62/62 - 0s - loss: 9.2411e-04 - val_loss: 0.0152 - 179ms/epoch - 3ms/step
# Epoch 44/200
# 62/62 - 0s - loss: 9.8674e-04 - val_loss: 0.0109 - 180ms/epoch - 3ms/step
# Epoch 45/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0158 - 181ms/epoch - 3ms/step
# Epoch 46/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0131 - 158ms/epoch - 3ms/step
# Epoch 47/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0107 - 164ms/epoch - 3ms/step
# Epoch 48/200
# 62/62 - 0s - loss: 9.7982e-04 - val_loss: 0.0196 - 183ms/epoch - 3ms/step
# Epoch 49/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0144 - 184ms/epoch - 3ms/step
# Epoch 50/200
# 62/62 - 0s - loss: 9.8932e-04 - val_loss: 0.0205 - 181ms/epoch - 3ms/step
# Epoch 51/200
# 62/62 - 0s - loss: 9.1836e-04 - val_loss: 0.0131 - 168ms/epoch - 3ms/step
# Epoch 52/200
# 62/62 - 0s - loss: 9.4569e-04 - val_loss: 0.0078 - 154ms/epoch - 2ms/step
# Epoch 53/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0141 - 167ms/epoch - 3ms/step
# Epoch 54/200
# 62/62 - 0s - loss: 9.9923e-04 - val_loss: 0.0156 - 190ms/epoch - 3ms/step
# Epoch 55/200
# 62/62 - 0s - loss: 9.8798e-04 - val_loss: 0.0099 - 153ms/epoch - 2ms/step
# Epoch 56/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0210 - 183ms/epoch - 3ms/step
# Epoch 57/200
# 62/62 - 0s - loss: 9.0671e-04 - val_loss: 0.0139 - 180ms/epoch - 3ms/step
# Epoch 58/200
# 62/62 - 0s - loss: 9.9575e-04 - val_loss: 0.0098 - 179ms/epoch - 3ms/step
# Epoch 59/200
# 62/62 - 0s - loss: 9.7908e-04 - val_loss: 0.0139 - 238ms/epoch - 4ms/step
# Epoch 60/200
# 62/62 - 0s - loss: 9.5573e-04 - val_loss: 0.0138 - 232ms/epoch - 4ms/step
# Epoch 61/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0088 - 218ms/epoch - 4ms/step
# Epoch 62/200
# 62/62 - 0s - loss: 9.8248e-04 - val_loss: 0.0114 - 225ms/epoch - 4ms/step
# Epoch 63/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0136 - 221ms/epoch - 4ms/step
# Epoch 64/200
# 62/62 - 0s - loss: 9.6462e-04 - val_loss: 0.0187 - 215ms/epoch - 3ms/step
# Epoch 65/200
# 62/62 - 0s - loss: 9.5027e-04 - val_loss: 0.0128 - 224ms/epoch - 4ms/step
# Epoch 66/200
# 62/62 - 0s - loss: 9.0934e-04 - val_loss: 0.0148 - 240ms/epoch - 4ms/step
# Epoch 67/200
# 62/62 - 0s - loss: 0.0012 - val_loss: 0.0089 - 250ms/epoch - 4ms/step
# Epoch 68/200
# 62/62 - 0s - loss: 8.2549e-04 - val_loss: 0.0102 - 236ms/epoch - 4ms/step
# Epoch 69/200
# 62/62 - 0s - loss: 9.4942e-04 - val_loss: 0.0135 - 252ms/epoch - 4ms/step
# Epoch 70/200
# 62/62 - 0s - loss: 8.1462e-04 - val_loss: 0.0096 - 250ms/epoch - 4ms/step
# Epoch 71/200
# 62/62 - 0s - loss: 9.2494e-04 - val_loss: 0.0152 - 359ms/epoch - 6ms/step
# Epoch 72/200
# 62/62 - 0s - loss: 8.5648e-04 - val_loss: 0.0186 - 207ms/epoch - 3ms/step
# Epoch 73/200
# 62/62 - 0s - loss: 8.5799e-04 - val_loss: 0.0175 - 161ms/epoch - 3ms/step
# Epoch 74/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0125 - 194ms/epoch - 3ms/step
# Epoch 75/200
# 62/62 - 0s - loss: 8.7124e-04 - val_loss: 0.0109 - 179ms/epoch - 3ms/step
# Epoch 76/200
# 62/62 - 0s - loss: 9.1241e-04 - val_loss: 0.0140 - 167ms/epoch - 3ms/step
# Epoch 77/200
# 62/62 - 0s - loss: 8.6396e-04 - val_loss: 0.0161 - 165ms/epoch - 3ms/step
# Epoch 78/200
# 62/62 - 0s - loss: 9.3127e-04 - val_loss: 0.0120 - 180ms/epoch - 3ms/step
# Epoch 79/200
# 62/62 - 0s - loss: 9.3283e-04 - val_loss: 0.0153 - 182ms/epoch - 3ms/step
# Epoch 80/200
# 62/62 - 0s - loss: 8.7465e-04 - val_loss: 0.0135 - 156ms/epoch - 3ms/step
# Epoch 81/200
# 62/62 - 0s - loss: 9.2997e-04 - val_loss: 0.0136 - 192ms/epoch - 3ms/step
# Epoch 82/200
# 62/62 - 0s - loss: 8.7748e-04 - val_loss: 0.0125 - 190ms/epoch - 3ms/step
# Epoch 83/200
# 62/62 - 0s - loss: 9.3299e-04 - val_loss: 0.0170 - 162ms/epoch - 3ms/step
# Epoch 84/200
# 62/62 - 0s - loss: 8.6336e-04 - val_loss: 0.0128 - 162ms/epoch - 3ms/step
# Epoch 85/200
# 62/62 - 0s - loss: 9.0561e-04 - val_loss: 0.0132 - 156ms/epoch - 3ms/step
# Epoch 86/200
# 62/62 - 0s - loss: 8.7324e-04 - val_loss: 0.0130 - 161ms/epoch - 3ms/step
# Epoch 87/200
# 62/62 - 0s - loss: 8.8594e-04 - val_loss: 0.0115 - 182ms/epoch - 3ms/step
# Epoch 88/200
# 62/62 - 0s - loss: 9.6853e-04 - val_loss: 0.0142 - 181ms/epoch - 3ms/step
# Epoch 89/200
# 62/62 - 0s - loss: 9.5047e-04 - val_loss: 0.0154 - 183ms/epoch - 3ms/step
# Epoch 90/200
# 62/62 - 0s - loss: 9.3491e-04 - val_loss: 0.0135 - 180ms/epoch - 3ms/step
# Epoch 91/200
# 62/62 - 0s - loss: 9.6987e-04 - val_loss: 0.0130 - 185ms/epoch - 3ms/step
# Epoch 92/200
# 62/62 - 0s - loss: 8.9793e-04 - val_loss: 0.0128 - 183ms/epoch - 3ms/step
# Epoch 93/200
# 62/62 - 0s - loss: 9.3100e-04 - val_loss: 0.0111 - 167ms/epoch - 3ms/step
# Epoch 94/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0160 - 156ms/epoch - 3ms/step
# Epoch 95/200
# 62/62 - 0s - loss: 9.1506e-04 - val_loss: 0.0134 - 179ms/epoch - 3ms/step
# Epoch 96/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0167 - 154ms/epoch - 2ms/step
# Epoch 97/200
# 62/62 - 0s - loss: 9.3227e-04 - val_loss: 0.0126 - 154ms/epoch - 2ms/step
# Epoch 98/200
# 62/62 - 0s - loss: 9.1325e-04 - val_loss: 0.0110 - 183ms/epoch - 3ms/step
# Epoch 99/200
# 62/62 - 0s - loss: 9.4794e-04 - val_loss: 0.0165 - 199ms/epoch - 3ms/step
# Epoch 100/200
# 62/62 - 0s - loss: 9.1655e-04 - val_loss: 0.0132 - 181ms/epoch - 3ms/step
# Epoch 101/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0088 - 179ms/epoch - 3ms/step
# Epoch 102/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0094 - 180ms/epoch - 3ms/step
# Epoch 103/200
# 62/62 - 0s - loss: 8.6184e-04 - val_loss: 0.0159 - 153ms/epoch - 2ms/step
# Epoch 104/200
# 62/62 - 0s - loss: 8.8536e-04 - val_loss: 0.0143 - 175ms/epoch - 3ms/step
# Epoch 105/200
# 62/62 - 0s - loss: 9.5652e-04 - val_loss: 0.0124 - 167ms/epoch - 3ms/step
# Epoch 106/200
# 62/62 - 0s - loss: 8.5421e-04 - val_loss: 0.0100 - 158ms/epoch - 3ms/step
# Epoch 107/200
# 62/62 - 0s - loss: 8.9090e-04 - val_loss: 0.0108 - 182ms/epoch - 3ms/step
# Epoch 108/200
# 62/62 - 0s - loss: 8.4270e-04 - val_loss: 0.0145 - 157ms/epoch - 3ms/step
# Epoch 109/200
# 62/62 - 0s - loss: 9.7672e-04 - val_loss: 0.0102 - 186ms/epoch - 3ms/step
# Epoch 110/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0120 - 195ms/epoch - 3ms/step
# Epoch 111/200
# 62/62 - 0s - loss: 9.6786e-04 - val_loss: 0.0142 - 160ms/epoch - 3ms/step
# Epoch 112/200
# 62/62 - 0s - loss: 9.1386e-04 - val_loss: 0.0121 - 182ms/epoch - 3ms/step
# Epoch 113/200
# 62/62 - 0s - loss: 9.0745e-04 - val_loss: 0.0144 - 184ms/epoch - 3ms/step
# Epoch 114/200
# 62/62 - 0s - loss: 8.6981e-04 - val_loss: 0.0074 - 158ms/epoch - 3ms/step
# Epoch 115/200
# 62/62 - 0s - loss: 9.0285e-04 - val_loss: 0.0119 - 169ms/epoch - 3ms/step
# Epoch 116/200
# 62/62 - 0s - loss: 8.9304e-04 - val_loss: 0.0107 - 172ms/epoch - 3ms/step
# Epoch 117/200
# 62/62 - 0s - loss: 8.8618e-04 - val_loss: 0.0120 - 181ms/epoch - 3ms/step
# Epoch 118/200
# 62/62 - 0s - loss: 9.5619e-04 - val_loss: 0.0113 - 186ms/epoch - 3ms/step
# Epoch 119/200
# 62/62 - 0s - loss: 8.4558e-04 - val_loss: 0.0136 - 161ms/epoch - 3ms/step
# Epoch 120/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0166 - 181ms/epoch - 3ms/step
# Epoch 121/200
# 62/62 - 0s - loss: 8.9046e-04 - val_loss: 0.0132 - 167ms/epoch - 3ms/step
# Epoch 122/200
# 62/62 - 0s - loss: 8.4452e-04 - val_loss: 0.0193 - 188ms/epoch - 3ms/step
# Epoch 123/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0078 - 183ms/epoch - 3ms/step
# Epoch 124/200
# 62/62 - 0s - loss: 9.1513e-04 - val_loss: 0.0121 - 156ms/epoch - 3ms/step
# Epoch 125/200
# 62/62 - 0s - loss: 9.5929e-04 - val_loss: 0.0125 - 183ms/epoch - 3ms/step
# Epoch 126/200
# 62/62 - 0s - loss: 9.7952e-04 - val_loss: 0.0151 - 183ms/epoch - 3ms/step
# Epoch 127/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0136 - 178ms/epoch - 3ms/step
# Epoch 128/200
# 62/62 - 0s - loss: 9.5921e-04 - val_loss: 0.0109 - 223ms/epoch - 4ms/step
# Epoch 129/200
# 62/62 - 0s - loss: 9.2592e-04 - val_loss: 0.0163 - 233ms/epoch - 4ms/step
# Epoch 130/200
# 62/62 - 0s - loss: 8.3605e-04 - val_loss: 0.0109 - 237ms/epoch - 4ms/step
# Epoch 131/200
# 62/62 - 0s - loss: 9.6568e-04 - val_loss: 0.0094 - 252ms/epoch - 4ms/step
# Epoch 132/200
# 62/62 - 0s - loss: 9.6684e-04 - val_loss: 0.0158 - 232ms/epoch - 4ms/step
# Epoch 133/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0094 - 226ms/epoch - 4ms/step
# Epoch 134/200
# 62/62 - 0s - loss: 9.0323e-04 - val_loss: 0.0107 - 235ms/epoch - 4ms/step
# Epoch 135/200
# 62/62 - 0s - loss: 8.3950e-04 - val_loss: 0.0177 - 265ms/epoch - 4ms/step
# Epoch 136/200
# 62/62 - 0s - loss: 9.9874e-04 - val_loss: 0.0169 - 341ms/epoch - 5ms/step
# Epoch 137/200
# 62/62 - 0s - loss: 9.3494e-04 - val_loss: 0.0126 - 238ms/epoch - 4ms/step
# Epoch 138/200
# 62/62 - 0s - loss: 9.0715e-04 - val_loss: 0.0143 - 231ms/epoch - 4ms/step
# Epoch 139/200
# 62/62 - 0s - loss: 8.8360e-04 - val_loss: 0.0122 - 257ms/epoch - 4ms/step
# Epoch 140/200
# 62/62 - 0s - loss: 9.0528e-04 - val_loss: 0.0092 - 251ms/epoch - 4ms/step
# Epoch 141/200
# 62/62 - 0s - loss: 9.2082e-04 - val_loss: 0.0099 - 255ms/epoch - 4ms/step
# Epoch 142/200
# 62/62 - 0s - loss: 6.9716e-04 - val_loss: 0.0059 - 199ms/epoch - 3ms/step
# Epoch 143/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0139 - 192ms/epoch - 3ms/step
# Epoch 144/200
# 62/62 - 0s - loss: 9.0435e-04 - val_loss: 0.0145 - 190ms/epoch - 3ms/step
# Epoch 145/200
# 62/62 - 0s - loss: 9.2891e-04 - val_loss: 0.0136 - 173ms/epoch - 3ms/step
# Epoch 146/200
# 62/62 - 0s - loss: 9.9689e-04 - val_loss: 0.0153 - 171ms/epoch - 3ms/step
# Epoch 147/200
# 62/62 - 0s - loss: 8.7490e-04 - val_loss: 0.0140 - 167ms/epoch - 3ms/step
# Epoch 148/200
# 62/62 - 0s - loss: 9.2359e-04 - val_loss: 0.0136 - 195ms/epoch - 3ms/step
# Epoch 149/200
# 62/62 - 0s - loss: 8.6463e-04 - val_loss: 0.0125 - 168ms/epoch - 3ms/step
# Epoch 150/200
# 62/62 - 0s - loss: 9.1229e-04 - val_loss: 0.0099 - 166ms/epoch - 3ms/step
# Epoch 151/200
# 62/62 - 0s - loss: 8.6875e-04 - val_loss: 0.0132 - 198ms/epoch - 3ms/step
# Epoch 152/200
# 62/62 - 0s - loss: 8.8801e-04 - val_loss: 0.0117 - 193ms/epoch - 3ms/step
# Epoch 153/200
# 62/62 - 0s - loss: 8.2858e-04 - val_loss: 0.0160 - 200ms/epoch - 3ms/step
# Epoch 154/200
# 62/62 - 0s - loss: 9.8194e-04 - val_loss: 0.0114 - 197ms/epoch - 3ms/step
# Epoch 155/200
# 62/62 - 0s - loss: 9.7708e-04 - val_loss: 0.0104 - 208ms/epoch - 3ms/step
# Epoch 156/200
# 62/62 - 0s - loss: 8.6353e-04 - val_loss: 0.0156 - 232ms/epoch - 4ms/step
# Epoch 157/200
# 62/62 - 0s - loss: 8.8884e-04 - val_loss: 0.0114 - 220ms/epoch - 4ms/step
# Epoch 158/200
# 62/62 - 0s - loss: 9.1626e-04 - val_loss: 0.0146 - 198ms/epoch - 3ms/step
# Epoch 159/200
# 62/62 - 0s - loss: 8.5673e-04 - val_loss: 0.0155 - 197ms/epoch - 3ms/step
# Epoch 160/200
# 62/62 - 0s - loss: 9.2107e-04 - val_loss: 0.0152 - 173ms/epoch - 3ms/step
# Epoch 161/200
# 62/62 - 0s - loss: 9.5215e-04 - val_loss: 0.0168 - 194ms/epoch - 3ms/step
# Epoch 162/200
# 62/62 - 0s - loss: 9.7706e-04 - val_loss: 0.0120 - 170ms/epoch - 3ms/step
# Epoch 163/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0101 - 214ms/epoch - 3ms/step
# Epoch 164/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0158 - 181ms/epoch - 3ms/step
# Epoch 165/200
# 62/62 - 0s - loss: 9.4581e-04 - val_loss: 0.0151 - 195ms/epoch - 3ms/step
# Epoch 166/200
# 62/62 - 0s - loss: 9.3761e-04 - val_loss: 0.0124 - 199ms/epoch - 3ms/step
# Epoch 167/200
# 62/62 - 0s - loss: 8.5552e-04 - val_loss: 0.0144 - 193ms/epoch - 3ms/step
# Epoch 168/200
# 62/62 - 0s - loss: 8.5257e-04 - val_loss: 0.0125 - 178ms/epoch - 3ms/step
# Epoch 169/200
# 62/62 - 0s - loss: 8.7899e-04 - val_loss: 0.0123 - 200ms/epoch - 3ms/step
# Epoch 170/200
# 62/62 - 0s - loss: 9.1716e-04 - val_loss: 0.0108 - 177ms/epoch - 3ms/step
# Epoch 171/200
# 62/62 - 0s - loss: 0.0011 - val_loss: 0.0107 - 224ms/epoch - 4ms/step
# Epoch 172/200
# 62/62 - 0s - loss: 8.9352e-04 - val_loss: 0.0106 - 212ms/epoch - 3ms/step
# Epoch 173/200
# 62/62 - 0s - loss: 8.6800e-04 - val_loss: 0.0118 - 227ms/epoch - 4ms/step
# Epoch 174/200
# 62/62 - 0s - loss: 8.7969e-04 - val_loss: 0.0116 - 224ms/epoch - 4ms/step
# Epoch 175/200
# 62/62 - 0s - loss: 8.3949e-04 - val_loss: 0.0135 - 225ms/epoch - 4ms/step
# Epoch 176/200
# 62/62 - 0s - loss: 8.5388e-04 - val_loss: 0.0122 - 224ms/epoch - 4ms/step
# Epoch 177/200
# 62/62 - 0s - loss: 8.5105e-04 - val_loss: 0.0109 - 201ms/epoch - 3ms/step
# Epoch 178/200
# 62/62 - 0s - loss: 9.9445e-04 - val_loss: 0.0109 - 229ms/epoch - 4ms/step
# Epoch 179/200
# 62/62 - 0s - loss: 9.6479e-04 - val_loss: 0.0095 - 201ms/epoch - 3ms/step
# Epoch 180/200
# 62/62 - 0s - loss: 9.6437e-04 - val_loss: 0.0100 - 219ms/epoch - 4ms/step
# Epoch 181/200
# 62/62 - 0s - loss: 9.4003e-04 - val_loss: 0.0109 - 223ms/epoch - 4ms/step
# Epoch 182/200
# 62/62 - 0s - loss: 9.2541e-04 - val_loss: 0.0150 - 184ms/epoch - 3ms/step
# Epoch 183/200
# 62/62 - 0s - loss: 8.8922e-04 - val_loss: 0.0113 - 195ms/epoch - 3ms/step
# Epoch 184/200
# 62/62 - 0s - loss: 8.9504e-04 - val_loss: 0.0142 - 168ms/epoch - 3ms/step
# Epoch 185/200
# 62/62 - 0s - loss: 8.8061e-04 - val_loss: 0.0133 - 186ms/epoch - 3ms/step
# Epoch 186/200
# 62/62 - 0s - loss: 9.3407e-04 - val_loss: 0.0120 - 217ms/epoch - 3ms/step
# Epoch 187/200
# 62/62 - 0s - loss: 9.0197e-04 - val_loss: 0.0118 - 204ms/epoch - 3ms/step
# Epoch 188/200
# 62/62 - 0s - loss: 8.8315e-04 - val_loss: 0.0151 - 196ms/epoch - 3ms/step
# Epoch 189/200
# 62/62 - 0s - loss: 8.5398e-04 - val_loss: 0.0119 - 214ms/epoch - 3ms/step
# Epoch 190/200
# 62/62 - 0s - loss: 8.7357e-04 - val_loss: 0.0125 - 199ms/epoch - 3ms/step
# Epoch 191/200
# 62/62 - 0s - loss: 9.5479e-04 - val_loss: 0.0106 - 326ms/epoch - 5ms/step
# Epoch 192/200
# 62/62 - 0s - loss: 9.1401e-04 - val_loss: 0.0114 - 400ms/epoch - 6ms/step
# Epoch 193/200
# 62/62 - 0s - loss: 8.6397e-04 - val_loss: 0.0122 - 378ms/epoch - 6ms/step
# Epoch 194/200
# 62/62 - 0s - loss: 8.8454e-04 - val_loss: 0.0134 - 302ms/epoch - 5ms/step
# Epoch 195/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0143 - 278ms/epoch - 4ms/step
# Epoch 196/200
# 62/62 - 0s - loss: 0.0010 - val_loss: 0.0119 - 338ms/epoch - 5ms/step
# Epoch 197/200
# 62/62 - 0s - loss: 8.6221e-04 - val_loss: 0.0123 - 279ms/epoch - 4ms/step
# Epoch 198/200
# 62/62 - 0s - loss: 9.1106e-04 - val_loss: 0.0131 - 274ms/epoch - 4ms/step
# Epoch 199/200
# 62/62 - 0s - loss: 8.7872e-04 - val_loss: 0.0116 - 253ms/epoch - 4ms/step
# Epoch 200/200
# 62/62 - 0s - loss: 8.6389e-04 - val_loss: 0.0106 - 256ms/epoch - 4ms/step
# 2/2 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
